# %% [markdown]
# <a href="https://colab.research.google.com/github/divy-14/Algo_Ds/blob/master/number_plate_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Liscensed to Divy Mohan Rai(divy-14) and Utkarsh Sharma(kush-13
# )

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls
# !rm -fr darknet
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# drive  sample_data
# Cloning into 'darknet'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 12428 (delta 16), reused 11 (delta 5), pack-reused 12394
# Receiving objects: 100% (12428/12428), 11.51 MiB | 22.89 MiB/s, done.
# Resolving deltas: 100% (8440/8440), done.

# %%
cp drive/'My Drive'/data_for_colab.zip /content/darknet

# %%
cd darknet
# Out:
# /content/darknet

# %%
ls
# Out:
# 3rdparty/     CMakeLists.txt          image_yolov3.sh*        scripts/
# appveyor.yml  DarknetConfig.cmake.in  include/                src/
# build/        darknet.py              json_mjpeg_streams.sh*  video_v2.sh*
# build.ps1*    darknet_video.py        LICENSE                 video_yolov3.sh*
# build.sh*     data/                   Makefile
# cfg/          data_for_colab.zip      net_cam_v3.sh*
# cmake/        image_yolov2.sh*        README.md

# %%
# !unzip data_for_colab
# Out:
# Archive:  data_for_colab.zip
#    creating: data_for_colab/data/
#   inflating: data_for_colab/data/image(0).jpg
#   inflating: data_for_colab/data/image(0).txt
#   inflating: data_for_colab/data/image(1).jpg
#   inflating: data_for_colab/data/image(1).txt
#   inflating: data_for_colab/data/image(10).jpg
#   inflating: data_for_colab/data/image(10).txt
#   inflating: data_for_colab/data/image(100).jpg
#   inflating: data_for_colab/data/image(100).txt
#   inflating: data_for_colab/data/image(101).jpg
#   inflating: data_for_colab/data/image(101).txt
#   inflating: data_for_colab/data/image(102).jpg
#   inflating: data_for_colab/data/image(102).txt
#   inflating: data_for_colab/data/image(103).jpg
#   inflating: data_for_colab/data/image(103).txt
#   inflating: data_for_colab/data/image(104).jpg
#   inflating: data_for_colab/data/image(104).txt
#   inflating: data_for_colab/data/image(105).jpg
#   inflating: data_for_colab/data/image(105).txt
#   inflating: data_for_colab/data/image(106).jpg
#   inflating: data_for_colab/data/image(106).txt
#   inflating: data_for_colab/data/image(108).jpg
#   inflating: data_for_colab/data/image(108).txt
#   inflating: data_for_colab/data/image(109).jpg
#   inflating: data_for_colab/data/image(109).txt
#   inflating: data_for_colab/data/image(11).jpg
#   inflating: data_for_colab/data/image(11).txt
#   inflating: data_for_colab/data/image(110).jpg
#   inflating: data_for_colab/data/image(110).txt
#   inflating: data_for_colab/data/image(111).jpg
#   inflating: data_for_colab/data/image(111).txt
#   inflating: data_for_colab/data/image(112).jpg
#   inflating: data_for_colab/data/image(112).txt
#   inflating: data_for_colab/data/image(113).jpg
#   inflating: data_for_colab/data/image(113).txt
#   inflating: data_for_colab/data/image(114).jpg
#   inflating: data_for_colab/data/image(114).txt
#   inflating: data_for_colab/data/image(115).jpg
#   inflating: data_for_colab/data/image(115).txt
#   inflating: data_for_colab/data/image(116).jpg
#   inflating: data_for_colab/data/image(116).txt
#   inflating: data_for_colab/data/image(117).jpg
#   inflating: data_for_colab/data/image(117).txt
#   inflating: data_for_colab/data/image(118).jpg
#   inflating: data_for_colab/data/image(118).txt
#   inflating: data_for_colab/data/image(119).jpg
#   inflating: data_for_colab/data/image(119).txt
#   inflating: data_for_colab/data/image(12).jpg
#   inflating: data_for_colab/data/image(12).txt
#   inflating: data_for_colab/data/image(120).jpg
#   inflating: data_for_colab/data/image(120).txt
#   inflating: data_for_colab/data/image(121).jpg
#   inflating: data_for_colab/data/image(121).txt
#   inflating: data_for_colab/data/image(122).jpg
#   inflating: data_for_colab/data/image(122).txt
#   inflating: data_for_colab/data/image(123).jpg
#   inflating: data_for_colab/data/image(123).txt
#   inflating: data_for_colab/data/image(124).jpg
#   inflating: data_for_colab/data/image(124).txt
#   inflating: data_for_colab/data/image(125).jpg
#   inflating: data_for_colab/data/image(125).txt
#   inflating: data_for_colab/data/image(126).jpg
#   inflating: data_for_colab/data/image(126).txt
#   inflating: data_for_colab/data/image(127).jpg
#   inflating: data_for_colab/data/image(127).txt
#   inflating: data_for_colab/data/image(128).jpg
#   inflating: data_for_colab/data/image(128).txt
#   inflating: data_for_colab/data/image(129).jpg
#   inflating: data_for_colab/data/image(129).txt
#   inflating: data_for_colab/data/image(13).jpg
#   inflating: data_for_colab/data/image(13).txt
#   inflating: data_for_colab/data/image(130).jpg
#   inflating: data_for_colab/data/image(130).txt
#   inflating: data_for_colab/data/image(131).jpg
#   inflating: data_for_colab/data/image(131).txt
#   inflating: data_for_colab/data/image(132).jpg
#   inflating: data_for_colab/data/image(132).txt
#   inflating: data_for_colab/data/image(133).jpg
#   inflating: data_for_colab/data/image(133).txt
#   inflating: data_for_colab/data/image(134).jpg
#   inflating: data_for_colab/data/image(134).txt
#   inflating: data_for_colab/data/image(135).jpg
#   inflating: data_for_colab/data/image(135).txt
#   inflating: data_for_colab/data/image(136).jpg
#   inflating: data_for_colab/data/image(136).txt
#   inflating: data_for_colab/data/image(137).jpg
#   inflating: data_for_colab/data/image(137).txt
#   inflating: data_for_colab/data/image(138).jpg
#   inflating: data_for_colab/data/image(138).txt
#   inflating: data_for_colab/data/image(139).jpg
#   inflating: data_for_colab/data/image(139).txt
#   inflating: data_for_colab/data/image(14).jpg
#   inflating: data_for_colab/data/image(14).txt
#   inflating: data_for_colab/data/image(140).jpg
#   inflating: data_for_colab/data/image(140).txt
#   inflating: data_for_colab/data/image(141).jpg
#   inflating: data_for_colab/data/image(141).txt
#   inflating: data_for_colab/data/image(142).jpg
#   inflating: data_for_colab/data/image(142).txt
#   inflating: data_for_colab/data/image(143).jpg
#   inflating: data_for_colab/data/image(143).txt
#   inflating: data_for_colab/data/image(144).jpg
#   inflating: data_for_colab/data/image(144).txt
#   inflating: data_for_colab/data/image(145).jpg
#   inflating: data_for_colab/data/image(145).txt
#   inflating: data_for_colab/data/image(146).jpg
#   inflating: data_for_colab/data/image(146).txt
#   inflating: data_for_colab/data/image(147).jpg
#   inflating: data_for_colab/data/image(147).txt
#   inflating: data_for_colab/data/image(148).jpg
#   inflating: data_for_colab/data/image(148).txt
#   inflating: data_for_colab/data/image(149).jpg
#   inflating: data_for_colab/data/image(149).txt
#   inflating: data_for_colab/data/image(15).jpg
#   inflating: data_for_colab/data/image(15).txt
#   inflating: data_for_colab/data/image(150).jpg
#   inflating: data_for_colab/data/image(150).txt
#   inflating: data_for_colab/data/image(151).jpg
#   inflating: data_for_colab/data/image(151).txt
#   inflating: data_for_colab/data/image(152).jpg
#   inflating: data_for_colab/data/image(152).txt
#   inflating: data_for_colab/data/image(153).jpg
#   inflating: data_for_colab/data/image(153).txt
#   inflating: data_for_colab/data/image(154).jpg
#   inflating: data_for_colab/data/image(154).txt
#   inflating: data_for_colab/data/image(155).jpg
#   inflating: data_for_colab/data/image(155).txt
#   inflating: data_for_colab/data/image(156).jpg
#   inflating: data_for_colab/data/image(156).txt
#   inflating: data_for_colab/data/image(157).jpg
#   inflating: data_for_colab/data/image(157).txt
#   inflating: data_for_colab/data/image(158).jpg
#   inflating: data_for_colab/data/image(158).txt
#   inflating: data_for_colab/data/image(159).jpg
#   inflating: data_for_colab/data/image(159).txt
#   inflating: data_for_colab/data/image(16).jpg
#   inflating: data_for_colab/data/image(16).txt
#   inflating: data_for_colab/data/image(160).jpg
#   inflating: data_for_colab/data/image(160).txt
#   inflating: data_for_colab/data/image(161).jpg
#   inflating: data_for_colab/data/image(161).txt
#   inflating: data_for_colab/data/image(162).jpg
#   inflating: data_for_colab/data/image(162).txt
#   inflating: data_for_colab/data/image(163).jpg
#   inflating: data_for_colab/data/image(163).txt
#   inflating: data_for_colab/data/image(164).jpg
#   inflating: data_for_colab/data/image(164).txt
#   inflating: data_for_colab/data/image(165).jpg
#   inflating: data_for_colab/data/image(165).txt
#   inflating: data_for_colab/data/image(166).jpg
#   inflating: data_for_colab/data/image(166).txt
#   inflating: data_for_colab/data/image(167).jpg
#   inflating: data_for_colab/data/image(167).txt
#   inflating: data_for_colab/data/image(168).jpg
#   inflating: data_for_colab/data/image(168).txt
#   inflating: data_for_colab/data/image(169).jpg
#   inflating: data_for_colab/data/image(169).txt
#   inflating: data_for_colab/data/image(17).jpg
#   inflating: data_for_colab/data/image(17).txt
#   inflating: data_for_colab/data/image(170).jpg
#   inflating: data_for_colab/data/image(170).txt
#   inflating: data_for_colab/data/image(171).jpg
#   inflating: data_for_colab/data/image(171).txt
#   inflating: data_for_colab/data/image(172).jpg
#   inflating: data_for_colab/data/image(172).txt
#   inflating: data_for_colab/data/image(173).jpg
#   inflating: data_for_colab/data/image(173).txt
#   inflating: data_for_colab/data/image(174).jpg
#   inflating: data_for_colab/data/image(174).txt
#   inflating: data_for_colab/data/image(175).jpg
#   inflating: data_for_colab/data/image(175).txt
#   inflating: data_for_colab/data/image(176).jpg
#   inflating: data_for_colab/data/image(176).txt
#   inflating: data_for_colab/data/image(177).jpg
#   inflating: data_for_colab/data/image(177).txt
#   inflating: data_for_colab/data/image(178).jpg
#   inflating: data_for_colab/data/image(178).txt
#   inflating: data_for_colab/data/image(179).jpg
#   inflating: data_for_colab/data/image(179).txt
#   inflating: data_for_colab/data/image(18).jpg
#   inflating: data_for_colab/data/image(18).txt
#   inflating: data_for_colab/data/image(180).jpg
#   inflating: data_for_colab/data/image(180).txt
#   inflating: data_for_colab/data/image(181).jpg
#   inflating: data_for_colab/data/image(181).txt
#   inflating: data_for_colab/data/image(182).jpg
#   inflating: data_for_colab/data/image(182).txt
#   inflating: data_for_colab/data/image(183).jpg
#   inflating: data_for_colab/data/image(183).txt
#   inflating: data_for_colab/data/image(184).jpg
#   inflating: data_for_colab/data/image(184).txt
#   inflating: data_for_colab/data/image(185).jpg
#   inflating: data_for_colab/data/image(185).txt
#   inflating: data_for_colab/data/image(186).jpg
#   inflating: data_for_colab/data/image(186).txt
#   inflating: data_for_colab/data/image(187).jpg
#   inflating: data_for_colab/data/image(187).txt
#   inflating: data_for_colab/data/image(188).jpg
#   inflating: data_for_colab/data/image(188).txt
#   inflating: data_for_colab/data/image(189).jpg
#   inflating: data_for_colab/data/image(189).txt
#   inflating: data_for_colab/data/image(19).jpg
#   inflating: data_for_colab/data/image(19).txt
#   inflating: data_for_colab/data/image(190).jpg
#   inflating: data_for_colab/data/image(190).txt
#   inflating: data_for_colab/data/image(191).jpg
#   inflating: data_for_colab/data/image(191).txt
#   inflating: data_for_colab/data/image(192).jpg
#   inflating: data_for_colab/data/image(192).txt
#   inflating: data_for_colab/data/image(193).jpg
#   inflating: data_for_colab/data/image(193).txt
#   inflating: data_for_colab/data/image(194).jpg
#   inflating: data_for_colab/data/image(194).txt
#   inflating: data_for_colab/data/image(195).jpg
#   inflating: data_for_colab/data/image(195).txt
#   inflating: data_for_colab/data/image(196).jpg
#   inflating: data_for_colab/data/image(196).txt
#   inflating: data_for_colab/data/image(197).jpg
#   inflating: data_for_colab/data/image(197).txt
#   inflating: data_for_colab/data/image(198).jpg
#   inflating: data_for_colab/data/image(198).txt
#   inflating: data_for_colab/data/image(199).jpg
#   inflating: data_for_colab/data/image(199).txt
#   inflating: data_for_colab/data/image(2).jpg
#   inflating: data_for_colab/data/image(2).txt
#   inflating: data_for_colab/data/image(20).jpg
#   inflating: data_for_colab/data/image(20).txt
#   inflating: data_for_colab/data/image(200).jpg
#   inflating: data_for_colab/data/image(200).txt
#   inflating: data_for_colab/data/image(201).jpg
#   inflating: data_for_colab/data/image(201).txt
#   inflating: data_for_colab/data/image(202).jpg
#   inflating: data_for_colab/data/image(202).txt
#   inflating: data_for_colab/data/image(203).jpg
#   inflating: data_for_colab/data/image(203).txt
#   inflating: data_for_colab/data/image(204).jpg
#   inflating: data_for_colab/data/image(204).txt
#   inflating: data_for_colab/data/image(205).jpg
#   inflating: data_for_colab/data/image(205).txt
#   inflating: data_for_colab/data/image(206).jpg
#   inflating: data_for_colab/data/image(206).txt
#   inflating: data_for_colab/data/image(207).jpg
#   inflating: data_for_colab/data/image(207).txt
#   inflating: data_for_colab/data/image(208).jpg
#   inflating: data_for_colab/data/image(208).txt
#   inflating: data_for_colab/data/image(209).jpg
#   inflating: data_for_colab/data/image(209).txt
#   inflating: data_for_colab/data/image(21).jpg
#   inflating: data_for_colab/data/image(21).txt
#   inflating: data_for_colab/data/image(210).jpg
#   inflating: data_for_colab/data/image(210).txt
#   inflating: data_for_colab/data/image(211).jpg
#   inflating: data_for_colab/data/image(211).txt
#   inflating: data_for_colab/data/image(212).jpg
#   inflating: data_for_colab/data/image(212).txt
#   inflating: data_for_colab/data/image(213).jpg
#   inflating: data_for_colab/data/image(213).txt
#   inflating: data_for_colab/data/image(214).jpg
#   inflating: data_for_colab/data/image(214).txt
#   inflating: data_for_colab/data/image(215).jpg
#   inflating: data_for_colab/data/image(215).txt
#   inflating: data_for_colab/data/image(216).jpg
#   inflating: data_for_colab/data/image(216).txt
#   inflating: data_for_colab/data/image(217).jpg
#   inflating: data_for_colab/data/image(217).txt
#   inflating: data_for_colab/data/image(218).jpg
#   inflating: data_for_colab/data/image(218).txt
#   inflating: data_for_colab/data/image(219).jpg
#   inflating: data_for_colab/data/image(219).txt
#   inflating: data_for_colab/data/image(22).jpg
#   inflating: data_for_colab/data/image(22).txt
#   inflating: data_for_colab/data/image(220).jpg
#   inflating: data_for_colab/data/image(220).txt
#   inflating: data_for_colab/data/image(221).jpg
#   inflating: data_for_colab/data/image(221).txt
#   inflating: data_for_colab/data/image(222).jpg
#   inflating: data_for_colab/data/image(222).txt
#   inflating: data_for_colab/data/image(223).jpg
#   inflating: data_for_colab/data/image(223).txt
#   inflating: data_for_colab/data/image(224).jpg
#   inflating: data_for_colab/data/image(224).txt
#   inflating: data_for_colab/data/image(225).jpg
#   inflating: data_for_colab/data/image(225).txt
#   inflating: data_for_colab/data/image(226).jpg
#   inflating: data_for_colab/data/image(226).txt
#   inflating: data_for_colab/data/image(227).jpg
#   inflating: data_for_colab/data/image(227).txt
#   inflating: data_for_colab/data/image(228).jpg
#   inflating: data_for_colab/data/image(228).txt
#   inflating: data_for_colab/data/image(229).jpg
#   inflating: data_for_colab/data/image(229).txt
#   inflating: data_for_colab/data/image(23).jpg
#   inflating: data_for_colab/data/image(23).txt
#   inflating: data_for_colab/data/image(230).jpg
#   inflating: data_for_colab/data/image(230).txt
#   inflating: data_for_colab/data/image(231).jpg
#   inflating: data_for_colab/data/image(231).txt
#   inflating: data_for_colab/data/image(232).jpg
#   inflating: data_for_colab/data/image(232).txt
#   inflating: data_for_colab/data/image(233).jpg
#   inflating: data_for_colab/data/image(233).txt
#   inflating: data_for_colab/data/image(234).jpg
#   inflating: data_for_colab/data/image(234).txt
#   inflating: data_for_colab/data/image(235).jpg
#   inflating: data_for_colab/data/image(235).txt
#   inflating: data_for_colab/data/image(236).jpg
#   inflating: data_for_colab/data/image(236).txt
#   inflating: data_for_colab/data/image(24).jpg
#   inflating: data_for_colab/data/image(24).txt
#   inflating: data_for_colab/data/image(25).jpg
#   inflating: data_for_colab/data/image(25).txt
#   inflating: data_for_colab/data/image(26).jpg
#   inflating: data_for_colab/data/image(26).txt
#   inflating: data_for_colab/data/image(27).jpg
#   inflating: data_for_colab/data/image(27).txt
#   inflating: data_for_colab/data/image(28).jpg
#   inflating: data_for_colab/data/image(28).txt
#   inflating: data_for_colab/data/image(29).jpg
#   inflating: data_for_colab/data/image(29).txt
#   inflating: data_for_colab/data/image(3).jpg
#   inflating: data_for_colab/data/image(3).txt
#   inflating: data_for_colab/data/image(30).jpg
#   inflating: data_for_colab/data/image(30).txt
#   inflating: data_for_colab/data/image(31).jpg
#   inflating: data_for_colab/data/image(31).txt
#   inflating: data_for_colab/data/image(32).jpg
#   inflating: data_for_colab/data/image(32).txt
#   inflating: data_for_colab/data/image(33).jpg
#   inflating: data_for_colab/data/image(33).txt
#   inflating: data_for_colab/data/image(34).jpg
#   inflating: data_for_colab/data/image(34).txt
#   inflating: data_for_colab/data/image(35).jpg
#   inflating: data_for_colab/data/image(35).txt
#   inflating: data_for_colab/data/image(36).jpg
#  extracting: data_for_colab/data/image(36).txt
#   inflating: data_for_colab/data/image(37).jpg
#   inflating: data_for_colab/data/image(37).txt
#   inflating: data_for_colab/data/image(38).jpg
#   inflating: data_for_colab/data/image(38).txt
#   inflating: data_for_colab/data/image(39).jpg
#   inflating: data_for_colab/data/image(39).txt
#   inflating: data_for_colab/data/image(4).jpg
#   inflating: data_for_colab/data/image(4).txt
#   inflating: data_for_colab/data/image(40).jpg
#   inflating: data_for_colab/data/image(40).txt
#   inflating: data_for_colab/data/image(41).jpg
#   inflating: data_for_colab/data/image(41).txt
#   inflating: data_for_colab/data/image(42).jpg
#   inflating: data_for_colab/data/image(42).txt
#   inflating: data_for_colab/data/image(43).jpg
#   inflating: data_for_colab/data/image(43).txt
#   inflating: data_for_colab/data/image(44).jpg
#   inflating: data_for_colab/data/image(44).txt
#   inflating: data_for_colab/data/image(45).jpg
#   inflating: data_for_colab/data/image(45).txt
#   inflating: data_for_colab/data/image(46).jpg
#   inflating: data_for_colab/data/image(46).txt
#   inflating: data_for_colab/data/image(47).jpg
#   inflating: data_for_colab/data/image(47).txt
#   inflating: data_for_colab/data/image(48).jpg
#   inflating: data_for_colab/data/image(48).txt
#   inflating: data_for_colab/data/image(49).jpg
#   inflating: data_for_colab/data/image(49).txt
#   inflating: data_for_colab/data/image(5).jpg
#   inflating: data_for_colab/data/image(5).txt
#   inflating: data_for_colab/data/image(50).jpg
#   inflating: data_for_colab/data/image(50).txt
#   inflating: data_for_colab/data/image(51).jpg
#   inflating: data_for_colab/data/image(51).txt
#   inflating: data_for_colab/data/image(52).jpg
#   inflating: data_for_colab/data/image(52).txt
#   inflating: data_for_colab/data/image(53).jpg
#   inflating: data_for_colab/data/image(53).txt
#   inflating: data_for_colab/data/image(54).jpg
#   inflating: data_for_colab/data/image(54).txt
#   inflating: data_for_colab/data/image(55).jpg
#   inflating: data_for_colab/data/image(55).txt
#   inflating: data_for_colab/data/image(56).jpg
#   inflating: data_for_colab/data/image(56).txt
#   inflating: data_for_colab/data/image(57).jpg
#   inflating: data_for_colab/data/image(57).txt
#   inflating: data_for_colab/data/image(58).jpg
#   inflating: data_for_colab/data/image(58).txt
#   inflating: data_for_colab/data/image(59).jpg
#   inflating: data_for_colab/data/image(59).txt
#   inflating: data_for_colab/data/image(6).jpg
#   inflating: data_for_colab/data/image(6).txt
#   inflating: data_for_colab/data/image(60).jpg
#   inflating: data_for_colab/data/image(60).txt
#   inflating: data_for_colab/data/image(61).jpg
#   inflating: data_for_colab/data/image(61).txt
#   inflating: data_for_colab/data/image(62).jpg
#   inflating: data_for_colab/data/image(62).txt
#   inflating: data_for_colab/data/image(63).jpg
#   inflating: data_for_colab/data/image(63).txt
#   inflating: data_for_colab/data/image(64).jpg
#   inflating: data_for_colab/data/image(64).txt
#   inflating: data_for_colab/data/image(65).jpg
#   inflating: data_for_colab/data/image(65).txt
#   inflating: data_for_colab/data/image(66).jpg
#   inflating: data_for_colab/data/image(66).txt
#   inflating: data_for_colab/data/image(67).jpg
#   inflating: data_for_colab/data/image(67).txt
#   inflating: data_for_colab/data/image(68).jpg
#   inflating: data_for_colab/data/image(68).txt
#   inflating: data_for_colab/data/image(69).jpg
#   inflating: data_for_colab/data/image(69).txt
#   inflating: data_for_colab/data/image(7).jpg
#   inflating: data_for_colab/data/image(7).txt
#   inflating: data_for_colab/data/image(70).jpg
#   inflating: data_for_colab/data/image(70).txt
#   inflating: data_for_colab/data/image(71).jpg
#   inflating: data_for_colab/data/image(71).txt
#   inflating: data_for_colab/data/image(72).jpg
#   inflating: data_for_colab/data/image(72).txt
#   inflating: data_for_colab/data/image(73).jpg
#   inflating: data_for_colab/data/image(73).txt
#   inflating: data_for_colab/data/image(74).jpg
#   inflating: data_for_colab/data/image(74).txt
#   inflating: data_for_colab/data/image(75).jpg
#   inflating: data_for_colab/data/image(75).txt
#   inflating: data_for_colab/data/image(76).jpg
#   inflating: data_for_colab/data/image(76).txt
#   inflating: data_for_colab/data/image(77).jpg
#   inflating: data_for_colab/data/image(77).txt
#   inflating: data_for_colab/data/image(78).jpg
#   inflating: data_for_colab/data/image(78).txt
#   inflating: data_for_colab/data/image(79).jpg
#   inflating: data_for_colab/data/image(79).txt
#   inflating: data_for_colab/data/image(8).jpg
#   inflating: data_for_colab/data/image(8).txt
#   inflating: data_for_colab/data/image(80).jpg
#   inflating: data_for_colab/data/image(80).txt
#   inflating: data_for_colab/data/image(81).jpg
#   inflating: data_for_colab/data/image(81).txt
#   inflating: data_for_colab/data/image(82).jpg
#   inflating: data_for_colab/data/image(82).txt
#   inflating: data_for_colab/data/image(83).jpg
#   inflating: data_for_colab/data/image(83).txt
#   inflating: data_for_colab/data/image(84).jpg
#   inflating: data_for_colab/data/image(84).txt
#   inflating: data_for_colab/data/image(85).jpg
#   inflating: data_for_colab/data/image(85).txt
#   inflating: data_for_colab/data/image(86).jpg
#   inflating: data_for_colab/data/image(86).txt
#   inflating: data_for_colab/data/image(87).jpg
#   inflating: data_for_colab/data/image(87).txt
#   inflating: data_for_colab/data/image(88).jpg
#   inflating: data_for_colab/data/image(88).txt
#   inflating: data_for_colab/data/image(89).jpg
#   inflating: data_for_colab/data/image(89).txt
#   inflating: data_for_colab/data/image(9).jpg
#   inflating: data_for_colab/data/image(9).txt
#   inflating: data_for_colab/data/image(90).jpg
#   inflating: data_for_colab/data/image(90).txt
#   inflating: data_for_colab/data/image(91).jpg
#   inflating: data_for_colab/data/image(91).txt
#   inflating: data_for_colab/data/image(92).jpg
#   inflating: data_for_colab/data/image(92).txt
#   inflating: data_for_colab/data/image(93).jpg
#   inflating: data_for_colab/data/image(93).txt
#   inflating: data_for_colab/data/image(94).jpg
#   inflating: data_for_colab/data/image(94).txt
#   inflating: data_for_colab/data/image(95).jpg
#   inflating: data_for_colab/data/image(95).txt
#   inflating: data_for_colab/data/image(96).jpg
#   inflating: data_for_colab/data/image(96).txt
#   inflating: data_for_colab/data/image(97).jpg
#   inflating: data_for_colab/data/image(97).txt
#   inflating: data_for_colab/data/image(98).jpg
#   inflating: data_for_colab/data/image(98).txt
#   inflating: data_for_colab/data/image(99).jpg
#   inflating: data_for_colab/data/image(99).txt
#   inflating: data_for_colab/obj.data
#  extracting: data_for_colab/obj.names
#   inflating: data_for_colab/test.txt
#   inflating: data_for_colab/train.txt
#   inflating: data_for_colab/yolov3-tiny.conv.15
#   inflating: data_for_colab/yolov3-tiny-obj.cfg

# %%
# %cd /content/darknet/
# #upload train test.txt files
from google.colab import files
uploaded = files.upload() 
for name, data in uploaded.items():
  with open(name, 'wb') as f:
    f.write(data)
    print ('saved file', name)
# Out:
#      <input type="file" id="files-e04763d6-2c6b-49cd-8b70-402b08d7ed3d" name="files[]" multiple disabled />
#      <output id="result-e04763d6-2c6b-49cd-8b70-402b08d7ed3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.txt to test.txt
# saved file test.txt

# %%
ls
# Out:
# 3rdparty/     CMakeLists.txt          image_yolov2.sh*        README.md
# appveyor.yml  DarknetConfig.cmake.in  image_yolov3.sh*        scripts/
# build/        darknet.py              include/                src/
# build.ps1*    darknet_video.py        json_mjpeg_streams.sh*  test.txt
# build.sh*     data/                   LICENSE                 train.txt
# cfg/          data_for_colab/         Makefile                video_v2.sh*
# cmake/        data_for_colab.zip      net_cam_v3.sh*          video_yolov3.sh*

# %%
# !apt-get update
# !apt-get upgrade
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:4 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [564 B]
# Get:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [82.0 kB]
# Get:13 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [132 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [30.4 kB]
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [36.8 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [26.1 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [797 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,092 kB]
# Get:21 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,765 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [807 kB]
# Get:23 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [6,779 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [39.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,340 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [10.8 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [4,243 B]
# Get:28 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [852 kB]
# Fetched 7,317 kB in 3s (2,295 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-430 r-cran-zeallot
# Use 'apt autoremove' to remove them.
# The following packages have been kept back:
#   libcublas-dev libcublas10 libcudnn7 libcudnn7-dev libgl1-mesa-dri
#   libnccl-dev libnccl2 linux-headers-generic
# The following packages will be upgraded:
#   e2fsprogs libbsd0 libcom-err2 libdrm-amdgpu1 libdrm-common libdrm-dev
#   libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libegl-mesa0
#   libegl1-mesa-dev libext2fs2 libgbm1 libgcrypt20 libgl1-mesa-dev
#   libglapi-mesa libgles2-mesa-dev libglx-mesa0 libgnutls30 libllvm8
#   libmysqlclient20 libnss3 libnvidia-cfg1-440 libnvidia-common-440
#   libnvidia-compute-440 libnvidia-decode-440 libnvidia-encode-440
#   libnvidia-fbc1-440 libnvidia-gl-440 libnvidia-ifr1-440 librados2 librbd1
#   libsasl2-2 libsasl2-modules-db libsqlite3-0 libss2 libwayland-egl1-mesa
#   linux-libc-dev mesa-common-dev nvidia-compute-utils-440 nvidia-dkms-440
#   nvidia-driver-440 nvidia-kernel-common-440 nvidia-kernel-source-440
#   nvidia-utils-440 openjdk-11-jre openjdk-11-jre-headless
#   openjdk-8-jdk-headless openjdk-8-jre-headless python-apt-common python3-apt
#   python3-software-properties r-cran-bh r-cran-boot r-cran-broom r-cran-callr
#   r-cran-cli r-cran-dbi r-cran-dt r-cran-fansi r-cran-foreign r-cran-gh
#   r-cran-hms r-cran-knitr r-cran-mass r-cran-mime r-cran-pillar
#   r-cran-prettyunits r-cran-rlang r-cran-rmarkdown r-cran-stringi r-cran-tidyr
#   r-cran-tidyselect r-cran-tinytex r-cran-vctrs software-properties-common
#   xserver-xorg-core-hwe-18.04 xserver-xorg-video-nvidia-440
# 79 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# Need to get 220 MB of archives.
# After this operation, 31.0 MB disk space will be freed.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libext2fs2 amd64 1.44.1-1ubuntu1.3 [157 kB]
# Get:2 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-common-440 all 440.48.02-0ubuntu0~~18.04.1 [11.3 kB]
# Get:3 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-driver-440 amd64 440.48.02-0ubuntu0~~18.04.1 [415 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 e2fsprogs amd64 1.44.1-1ubuntu1.3 [391 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcom-err2 amd64 1.44.1-1ubuntu1.3 [8,848 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgcrypt20 amd64 1.8.1-4ubuntu1.2 [417 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libss2 amd64 1.44.1-1ubuntu1.3 [11.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgnutls30 amd64 3.5.18-1ubuntu1.3 [646 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbsd0 amd64 0.8.7-1ubuntu0.1 [41.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsqlite3-0 amd64 3.22.0-1ubuntu0.2 [498 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-common all 2.4.99-1ubuntu1~18.04.1 [5,264 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-dev amd64 2.4.99-1ubuntu1~18.04.1 [125 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-intel1 amd64 2.4.99-1ubuntu1~18.04.1 [59.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-radeon1 amd64 2.4.99-1ubuntu1~18.04.1 [21.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-nouveau2 amd64 2.4.99-1ubuntu1~18.04.1 [16.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-amdgpu1 amd64 2.4.99-1ubuntu1~18.04.1 [18.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm2 amd64 2.4.99-1ubuntu1~18.04.1 [31.7 kB]
# Get:18 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-decode-440 amd64 440.48.02-0ubuntu0~~18.04.1 [1,026 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python-apt-common all 1.6.5ubuntu0.2 [17.0 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-apt amd64 1.6.5ubuntu0.2 [149 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libegl-mesa0 amd64 19.2.1-1ubuntu1~18.04.1 [95.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgbm1 amd64 19.2.1-1ubuntu1~18.04.1 [28.1 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglx-mesa0 amd64 19.2.1-1ubuntu1~18.04.1 [139 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglapi-mesa amd64 19.2.1-1ubuntu1~18.04.1 [26.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dev amd64 19.2.1-1ubuntu1~18.04.1 [6,172 B]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libegl1-mesa-dev amd64 19.2.1-1ubuntu1~18.04.1 [20.4 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 mesa-common-dev amd64 19.2.1-1ubuntu1~18.04.1 [660 kB]
# Get:28 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-compute-440 amd64 440.48.02-0ubuntu0~~18.04.1 [21.2 MB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgles2-mesa-dev amd64 19.2.1-1ubuntu1~18.04.1 [44.8 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libllvm8 amd64 1:8-3~ubuntu18.04.2 [13.6 MB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmysqlclient20 amd64 5.7.29-0ubuntu0.18.04.1 [690 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnss3 amd64 2:3.35-2ubuntu2.7 [1,135 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-xorg-core-hwe-18.04 amd64 2:1.20.5+git20191008-0ubuntu1~18.04.1 [1,332 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librbd1 amd64 12.2.12-0ubuntu0.18.04.4 [920 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librados2 amd64 12.2.12-0ubuntu0.18.04.4 [2,704 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-modules-db amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.1 [14.8 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsasl2-2 amd64 2.1.27~101-g0780600+dfsg-3ubuntu2.1 [49.2 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwayland-egl1-mesa amd64 19.2.1-1ubuntu1~18.04.1 [6,844 B]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-libc-dev amd64 4.15.0-76.86 [999 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre amd64 11.0.6+10-1ubuntu1~18.04.1 [34.5 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 openjdk-11-jre-headless amd64 11.0.6+10-1ubuntu1~18.04.1 [37.5 MB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk-headless amd64 8u242-b08-0ubuntu3~18.04 [8,268 kB]
# Get:43 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-gl-440 amd64 440.48.02-0ubuntu0~~18.04.1 [62.8 MB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre-headless amd64 8u242-b08-0ubuntu3~18.04 [27.5 MB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 software-properties-common all 0.96.24.32.12 [10.0 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-software-properties all 0.96.24.32.12 [23.6 kB]
# Get:47 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-dkms-440 amd64 440.48.02-0ubuntu0~~18.04.1 [27.5 kB]
# Get:48 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-kernel-source-440 amd64 440.48.02-0ubuntu0~~18.04.1 [13.1 MB]
# Get:49 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-kernel-common-440 amd64 440.48.02-0ubuntu0~~18.04.1 [11.2 kB]
# Get:50 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-compute-utils-440 amd64 440.48.02-0ubuntu0~~18.04.1 [74.7 kB]
# Get:51 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-encode-440 amd64 440.48.02-0ubuntu0~~18.04.1 [39.1 kB]
# Get:52 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 nvidia-utils-440 amd64 440.48.02-0ubuntu0~~18.04.1 [346 kB]
# Get:53 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 xserver-xorg-video-nvidia-440 amd64 440.48.02-0ubuntu0~~18.04.1 [1,479 kB]
# Get:54 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-ifr1-440 amd64 440.48.02-0ubuntu0~~18.04.1 [69.9 kB]
# Get:55 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-fbc1-440 amd64 440.48.02-0ubuntu0~~18.04.1 [50.3 kB]
# Get:56 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 libnvidia-cfg1-440 amd64 440.48.02-0ubuntu0~~18.04.1 [72.6 kB]
# Get:57 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-bh all 1.72.0-3-1cran1ppabionic0 [7,431 kB]
# Get:58 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-boot all 1.3-24-1cran1ppabionic0 [618 kB]
# Get:59 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-rlang amd64 0.4.3-1cran1ppabionic0 [1,006 kB]
# Get:60 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-stringi amd64 1.4.5-1cran1ppabionic0 [714 kB]
# Get:61 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-vctrs amd64 0.2.2-1cran1ppabionic0 [780 kB]
# Get:62 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-tidyselect all 1.0.0-1cran1ppabionic0 [191 kB]
# Get:63 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-tidyr amd64 1.0.2-1cran1ppabionic0 [709 kB]
# Get:64 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-broom all 0.5.4-1cran1ppabionic0 [1,926 kB]
# Get:65 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-callr all 3.4.1-1cran1ppabionic0 [308 kB]
# Get:66 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-fansi amd64 0.4.1-1cran1ppabionic0 [172 kB]
# Get:67 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-cli all 2.0.1-1cran1ppabionic0 [368 kB]
# Get:68 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-dbi all 1.1.0-1cran1ppabionic0 [551 kB]
# Get:69 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-dt all 0.11-1cran1ppabionic0 [719 kB]
# Get:70 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-foreign amd64 0.8.75-1ppabionic0 [233 kB]
# Get:71 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-gh all 1.1.0-1cran1ppabionic0 [110 kB]
# Get:72 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-hms all 0.5.3-1cran1ppabionic0 [103 kB]
# Get:73 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-knitr all 1.27-1cran1ppabionic0 [1,163 kB]
# Get:74 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-mass amd64 7.3-51.5-1cran1ppabionic0 [1,109 kB]
# Get:75 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-mime amd64 0.8-1cran1ppabionic0 [35.2 kB]
# Get:76 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-pillar all 1.4.3-1cran1ppabionic0 [177 kB]
# Get:77 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-prettyunits all 1.1.1-1cran1ppabionic0 [35.8 kB]
# Get:78 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-tinytex all 0.19-1cran1ppabionic0 [100 kB]
# Get:79 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 r-cran-rmarkdown all 2.1-1cran1ppabionic0 [2,606 kB]
# Fetched 220 MB in 30s (7,409 kB/s)
# Extracting templates from packages: 100%
# (Reading database ... 145674 files and directories currently installed.)
# Preparing to unpack .../libext2fs2_1.44.1-1ubuntu1.3_amd64.deb ...
# Unpacking libext2fs2:amd64 (1.44.1-1ubuntu1.3) over (1.44.1-1ubuntu1.2) ...
# Setting up libext2fs2:amd64 (1.44.1-1ubuntu1.3) ...
# (Reading database ... 145674 files and directories currently installed.)
# Preparing to unpack .../e2fsprogs_1.44.1-1ubuntu1.3_amd64.deb ...
# Unpacking e2fsprogs (1.44.1-1ubuntu1.3) over (1.44.1-1ubuntu1.2) ...
# Setting up e2fsprogs (1.44.1-1ubuntu1.3) ...
# (Reading database ... 145674 files and directories currently installed.)
# Preparing to unpack .../libcom-err2_1.44.1-1ubuntu1.3_amd64.deb ...
# Unpacking libcom-err2:amd64 (1.44.1-1ubuntu1.3) over (1.44.1-1ubuntu1.2) ...
# Setting up libcom-err2:amd64 (1.44.1-1ubuntu1.3) ...
# (Reading database ... 145674 files and directories currently installed.)
# Preparing to unpack .../libgcrypt20_1.8.1-4ubuntu1.2_amd64.deb ...
# Unpacking libgcrypt20:amd64 (1.8.1-4ubuntu1.2) over (1.8.1-4ubuntu1.1) ...
# Setting up libgcrypt20:amd64 (1.8.1-4ubuntu1.2) ...
# (Reading database ... 145674 files and directories currently installed.)
# Preparing to unpack .../libss2_1.44.1-1ubuntu1.3_amd64.deb ...
# Unpacking libss2:amd64 (1.44.1-1ubuntu1.3) over (1.44.1-1ubuntu1.2) ...
# Setting up libss2:amd64 (1.44.1-1ubuntu1.3) ...
# (Reading database ... 145674 files and directories currently installed.)
# Preparing to unpack .../libgnutls30_3.5.18-1ubuntu1.3_amd64.deb ...
# Unpacking libgnutls30:amd64 (3.5.18-1ubuntu1.3) over (3.5.18-1ubuntu1.1) ...
# Setting up libgnutls30:amd64 (3.5.18-1ubuntu1.3) ...
# (Reading database ... 145674 files and directories currently installed.)
# Preparing to unpack .../00-libbsd0_0.8.7-1ubuntu0.1_amd64.deb ...
# Unpacking libbsd0:amd64 (0.8.7-1ubuntu0.1) over (0.8.7-1) ...
# Preparing to unpack .../01-libsqlite3-0_3.22.0-1ubuntu0.2_amd64.deb ...
# Unpacking libsqlite3-0:amd64 (3.22.0-1ubuntu0.2) over (3.22.0-1ubuntu0.1) ...
# Preparing to unpack .../02-libdrm-common_2.4.99-1ubuntu1~18.04.1_all.deb ...
# Unpacking libdrm-common (2.4.99-1ubuntu1~18.04.1) over (2.4.97-1ubuntu1~18.04.1) ...
# Preparing to unpack .../03-libdrm-dev_2.4.99-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.99-1ubuntu1~18.04.1) over (2.4.97-1ubuntu1~18.04.1) ...
# Preparing to unpack .../04-libdrm-intel1_2.4.99-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libdrm-intel1:amd64 (2.4.99-1ubuntu1~18.04.1) over (2.4.97-1ubuntu1~18.04.1) ...
# Preparing to unpack .../05-libdrm-radeon1_2.4.99-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libdrm-radeon1:amd64 (2.4.99-1ubuntu1~18.04.1) over (2.4.97-1ubuntu1~18.04.1) ...
# Preparing to unpack .../06-libdrm-nouveau2_2.4.99-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libdrm-nouveau2:amd64 (2.4.99-1ubuntu1~18.04.1) over (2.4.97-1ubuntu1~18.04.1) ...
# Preparing to unpack .../07-libdrm-amdgpu1_2.4.99-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libdrm-amdgpu1:amd64 (2.4.99-1ubuntu1~18.04.1) over (2.4.97-1ubuntu1~18.04.1) ...
# Preparing to unpack .../08-libdrm2_2.4.99-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.99-1ubuntu1~18.04.1) over (2.4.97-1ubuntu1~18.04.1) ...
# Preparing to unpack .../09-python-apt-common_1.6.5ubuntu0.2_all.deb ...
# Unpacking python-apt-common (1.6.5ubuntu0.2) over (1.6.4) ...
# Preparing to unpack .../10-python3-apt_1.6.5ubuntu0.2_amd64.deb ...
# Unpacking python3-apt (1.6.5ubuntu0.2) over (1.6.4) ...
# Preparing to unpack .../11-libegl-mesa0_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libegl-mesa0:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Preparing to unpack .../12-libgbm1_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgbm1:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Preparing to unpack .../13-libglx-mesa0_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libglx-mesa0:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Preparing to unpack .../14-libglapi-mesa_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libglapi-mesa:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Preparing to unpack .../15-libgl1-mesa-dev_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Preparing to unpack .../16-libegl1-mesa-dev_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Preparing to unpack .../17-mesa-common-dev_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking mesa-common-dev:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Preparing to unpack .../18-libgles2-mesa-dev_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgles2-mesa-dev:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Preparing to unpack .../19-libllvm8_1%3a8-3~ubuntu18.04.2_amd64.deb ...
# Unpacking libllvm8:amd64 (1:8-3~ubuntu18.04.2) over (1:8-3~ubuntu18.04.1) ...
# Preparing to unpack .../20-libmysqlclient20_5.7.29-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libmysqlclient20:amd64 (5.7.29-0ubuntu0.18.04.1) over (5.7.28-0ubuntu0.18.04.4) ...
# Preparing to unpack .../21-libnss3_2%3a3.35-2ubuntu2.7_amd64.deb ...
# Unpacking libnss3:amd64 (2:3.35-2ubuntu2.7) over (2:3.35-2ubuntu2.6) ...
# Preparing to unpack .../22-libnvidia-common-440_440.48.02-0ubuntu0~~18.04.1_all.deb ...
# Unpacking libnvidia-common-440 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../23-nvidia-driver-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking nvidia-driver-440 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../24-libnvidia-decode-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking libnvidia-decode-440:amd64 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../25-libnvidia-compute-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking libnvidia-compute-440:amd64 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../26-libnvidia-gl-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-435
# Unpacking libnvidia-gl-440:amd64 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../27-nvidia-dkms-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Removing all DKMS Modules
# Done.
# Unpacking nvidia-dkms-440 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../28-nvidia-kernel-source-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-source-440 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../29-nvidia-kernel-common-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking nvidia-kernel-common-440 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../30-nvidia-compute-utils-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# System has not been booted with systemd as init system (PID 1). Can't operate.
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Unpacking nvidia-compute-utils-440 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../31-libnvidia-encode-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking libnvidia-encode-440:amd64 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../32-nvidia-utils-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking nvidia-utils-440 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../33-xserver-xorg-video-nvidia-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking xserver-xorg-video-nvidia-440 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../34-xserver-xorg-core-hwe-18.04_2%3a1.20.5+git20191008-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking xserver-xorg-core-hwe-18.04 (2:1.20.5+git20191008-0ubuntu1~18.04.1) over (2:1.20.4-1ubuntu3~18.04.1) ...
# Preparing to unpack .../35-libnvidia-ifr1-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking libnvidia-ifr1-440:amd64 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../36-libnvidia-fbc1-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking libnvidia-fbc1-440:amd64 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../37-libnvidia-cfg1-440_440.48.02-0ubuntu0~~18.04.1_amd64.deb ...
# Unpacking libnvidia-cfg1-440:amd64 (440.48.02-0ubuntu0~~18.04.1) over (440.44-0ubuntu0~0.18.04.1) ...
# Preparing to unpack .../38-librbd1_12.2.12-0ubuntu0.18.04.4_amd64.deb ...
# Unpacking librbd1 (12.2.12-0ubuntu0.18.04.4) over (12.2.12-0ubuntu0.18.04.3) ...
# Preparing to unpack .../39-librados2_12.2.12-0ubuntu0.18.04.4_amd64.deb ...
# Unpacking librados2 (12.2.12-0ubuntu0.18.04.4) over (12.2.12-0ubuntu0.18.04.3) ...
# Preparing to unpack .../40-libsasl2-modules-db_2.1.27~101-g0780600+dfsg-3ubuntu2.1_amd64.deb ...
# Unpacking libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.1) over (2.1.27~101-g0780600+dfsg-3ubuntu2) ...
# Preparing to unpack .../41-libsasl2-2_2.1.27~101-g0780600+dfsg-3ubuntu2.1_amd64.deb ...
# Unpacking libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.1) over (2.1.27~101-g0780600+dfsg-3ubuntu2) ...
# Preparing to unpack .../42-libwayland-egl1-mesa_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libwayland-egl1-mesa:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Preparing to unpack .../43-linux-libc-dev_4.15.0-76.86_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (4.15.0-76.86) over (4.15.0-72.81) ...
# Preparing to unpack .../44-openjdk-11-jre_11.0.6+10-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.6+10-1ubuntu1~18.04.1) over (11.0.5+10-0ubuntu1.1~18.04) ...
# Preparing to unpack .../45-openjdk-11-jre-headless_11.0.6+10-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking openjdk-11-jre-headless:amd64 (11.0.6+10-1ubuntu1~18.04.1) over (11.0.5+10-0ubuntu1.1~18.04) ...
# Preparing to unpack .../46-openjdk-8-jdk-headless_8u242-b08-0ubuntu3~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u242-b08-0ubuntu3~18.04) over (8u232-b09-0ubuntu1~18.04.1) ...
# Preparing to unpack .../47-openjdk-8-jre-headless_8u242-b08-0ubuntu3~18.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u242-b08-0ubuntu3~18.04) over (8u232-b09-0ubuntu1~18.04.1) ...
# Preparing to unpack .../48-software-properties-common_0.96.24.32.12_all.deb ...
# Unpacking software-properties-common (0.96.24.32.12) over (0.96.24.32.11) ...
# Preparing to unpack .../49-python3-software-properties_0.96.24.32.12_all.deb ...
# Unpacking python3-software-properties (0.96.24.32.12) over (0.96.24.32.11) ...
# Preparing to unpack .../50-r-cran-bh_1.72.0-3-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-bh (1.72.0-3-1cran1ppabionic0) over (1.69.0-1-1cran1ppabionic0) ...
# Preparing to unpack .../51-r-cran-boot_1.3-24-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-boot (1.3-24-1cran1ppabionic0) over (1.3-23-2bionic0) ...
# Preparing to unpack .../52-r-cran-rlang_0.4.3-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-rlang (0.4.3-1cran1ppabionic0) over (0.4.2-1cran1ppabionic0) ...
# Preparing to unpack .../53-r-cran-stringi_1.4.5-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-stringi (1.4.5-1cran1ppabionic0) over (1.4.3-1cran1ppabionic0) ...
# Preparing to unpack .../54-r-cran-vctrs_0.2.2-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-vctrs (0.2.2-1cran1ppabionic0) over (0.2.0-1cran1ppabionic0) ...
# Preparing to unpack .../55-r-cran-tidyselect_1.0.0-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-tidyselect (1.0.0-1cran1ppabionic0) over (0.2.5-1cran1ppabionic0) ...
# Preparing to unpack .../56-r-cran-tidyr_1.0.2-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-tidyr (1.0.2-1cran1ppabionic0) over (1.0.0-1cran1~ubuntu18.04.1~ppa1) ...
# Preparing to unpack .../57-r-cran-broom_0.5.4-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-broom (0.5.4-1cran1ppabionic0) over (0.5.2-1cran1ppabionic0) ...
# Preparing to unpack .../58-r-cran-callr_3.4.1-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-callr (3.4.1-1cran1ppabionic0) over (3.4.0-1cran1ppabionic0) ...
# Preparing to unpack .../59-r-cran-fansi_0.4.1-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-fansi (0.4.1-1cran1ppabionic0) over (0.4.0-1cran1ppabionic0) ...
# Preparing to unpack .../60-r-cran-cli_2.0.1-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-cli (2.0.1-1cran1ppabionic0) over (2.0.0-1cran1ppabionic0) ...
# Preparing to unpack .../61-r-cran-dbi_1.1.0-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-dbi (1.1.0-1cran1ppabionic0) over (1.0.0-3cran1ppa0bionic0) ...
# Preparing to unpack .../62-r-cran-dt_0.11-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-dt (0.11-1cran1ppabionic0) over (0.10-1cran1ppabionic0) ...
# Preparing to unpack .../63-r-cran-foreign_0.8.75-1ppabionic0_amd64.deb ...
# Unpacking r-cran-foreign (0.8.75-1ppabionic0) over (0.8.72-1ppabionic0) ...
# Preparing to unpack .../64-r-cran-gh_1.1.0-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-gh (1.1.0-1cran1ppabionic0) over (1.0.1-3cran1ppa0bionic0) ...
# Preparing to unpack .../65-r-cran-hms_0.5.3-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-hms (0.5.3-1cran1ppabionic0) over (0.5.2-1cran1ppabionic0) ...
# Preparing to unpack .../66-r-cran-knitr_1.27-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-knitr (1.27-1cran1ppabionic0) over (1.26-1cran1ppabionic0) ...
# Preparing to unpack .../67-r-cran-mass_7.3-51.5-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-mass (7.3-51.5-1cran1ppabionic0) over (7.3-51.4-2bionic0) ...
# Preparing to unpack .../68-r-cran-mime_0.8-1cran1ppabionic0_amd64.deb ...
# Unpacking r-cran-mime (0.8-1cran1ppabionic0) over (0.7-1cran1ppabionic0) ...
# Preparing to unpack .../69-r-cran-pillar_1.4.3-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-pillar (1.4.3-1cran1ppabionic0) over (1.4.2-1cran1ppabionic0) ...
# Preparing to unpack .../70-r-cran-prettyunits_1.1.1-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-prettyunits (1.1.1-1cran1ppabionic0) over (1.0.2-3cran2ppa0bionic0) ...
# Preparing to unpack .../71-r-cran-tinytex_0.19-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-tinytex (0.19-1cran1ppabionic0) over (0.18-1cran1ppabionic0) ...
# Preparing to unpack .../72-r-cran-rmarkdown_2.1-1cran1ppabionic0_all.deb ...
# Unpacking r-cran-rmarkdown (2.1-1cran1ppabionic0) over (2.0-1cran1ppabionic0) ...
# Setting up python-apt-common (1.6.5ubuntu0.2) ...
# Setting up r-cran-tinytex (0.19-1cran1ppabionic0) ...
# Setting up r-cran-callr (3.4.1-1cran1ppabionic0) ...
# Setting up r-cran-boot (1.3-24-1cran1ppabionic0) ...
# Setting up python3-apt (1.6.5ubuntu0.2) ...
# Setting up libllvm8:amd64 (1:8-3~ubuntu18.04.2) ...
# Setting up libnvidia-common-440 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up libnvidia-fbc1-440:amd64 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up libsasl2-modules-db:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.1) ...
# Setting up r-cran-foreign (0.8.75-1ppabionic0) ...
# Setting up r-cran-knitr (1.27-1cran1ppabionic0) ...
# Setting up linux-libc-dev:amd64 (4.15.0-76.86) ...
# Setting up libsasl2-2:amd64 (2.1.27~101-g0780600+dfsg-3ubuntu2.1) ...
# Setting up r-cran-fansi (0.4.1-1cran1ppabionic0) ...
# Setting up r-cran-prettyunits (1.1.1-1cran1ppabionic0) ...
# Setting up libnvidia-compute-440:amd64 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up libglapi-mesa:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Setting up libbsd0:amd64 (0.8.7-1ubuntu0.1) ...
# Setting up libdrm-common (2.4.99-1ubuntu1~18.04.1) ...
# Setting up nvidia-utils-440 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up nvidia-kernel-common-440 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up libnvidia-cfg1-440:amd64 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up r-cran-dt (0.11-1cran1ppabionic0) ...
# Setting up r-cran-dbi (1.1.0-1cran1ppabionic0) ...
# Setting up r-cran-stringi (1.4.5-1cran1ppabionic0) ...
# Setting up libwayland-egl1-mesa:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Setting up libsqlite3-0:amd64 (3.22.0-1ubuntu0.2) ...
# Setting up r-cran-bh (1.72.0-3-1cran1ppabionic0) ...
# Setting up python3-software-properties (0.96.24.32.12) ...
# Setting up libnvidia-decode-440:amd64 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up libmysqlclient20:amd64 (5.7.29-0ubuntu0.18.04.1) ...
# Setting up r-cran-mass (7.3-51.5-1cran1ppabionic0) ...
# Setting up nvidia-compute-utils-440 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up r-cran-mime (0.8-1cran1ppabionic0) ...
# Setting up r-cran-rmarkdown (2.1-1cran1ppabionic0) ...
# Setting up libnvidia-encode-440:amd64 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up r-cran-rlang (0.4.3-1cran1ppabionic0) ...
# Setting up nvidia-kernel-source-440 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up r-cran-cli (2.0.1-1cran1ppabionic0) ...
# Setting up libnvidia-gl-440:amd64 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up software-properties-common (0.96.24.32.12) ...
# Setting up libnss3:amd64 (2:3.35-2ubuntu2.7) ...
# Setting up r-cran-vctrs (0.2.2-1cran1ppabionic0) ...
# Setting up nvidia-dkms-440 (440.48.02-0ubuntu0~~18.04.1) ...
# Loading new nvidia-440.48.02 DKMS files...
# It is likely that 4.14.137+ belongs to a chroot's host
# Building for 4.15.0-72-generic
# Building for architecture x86_64
# Building initial module for 4.15.0-72-generic
# Done.
#
# nvidia:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-72-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-72-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-72-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-72-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up libdrm2:amd64 (2.4.99-1ubuntu1~18.04.1) ...
# Setting up librados2 (12.2.12-0ubuntu0.18.04.4) ...
# Setting up r-cran-gh (1.1.0-1cran1ppabionic0) ...
# Setting up libdrm-intel1:amd64 (2.4.99-1ubuntu1~18.04.1) ...
# Setting up r-cran-hms (0.5.3-1cran1ppabionic0) ...
# Setting up libnvidia-ifr1-440:amd64 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up r-cran-pillar (1.4.3-1cran1ppabionic0) ...
# Setting up libdrm-radeon1:amd64 (2.4.99-1ubuntu1~18.04.1) ...
# Setting up libdrm-nouveau2:amd64 (2.4.99-1ubuntu1~18.04.1) ...
# Setting up libglx-mesa0:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Setting up openjdk-8-jre-headless:amd64 (8u242-b08-0ubuntu3~18.04) ...
# Installing new version of config file /etc/java-8-openjdk/security/java.security ...
# Setting up r-cran-tidyselect (1.0.0-1cran1ppabionic0) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.99-1ubuntu1~18.04.1) ...
# Setting up openjdk-8-jdk-headless:amd64 (8u242-b08-0ubuntu3~18.04) ...
# Setting up libdrm-dev:amd64 (2.4.99-1ubuntu1~18.04.1) ...
# Setting up r-cran-tidyr (1.0.2-1cran1ppabionic0) ...
# Setting up libgbm1:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Setting up openjdk-11-jre-headless:amd64 (11.0.6+10-1ubuntu1~18.04.1) ...
# Installing new version of config file /etc/java-11-openjdk/jfr/default.jfc ...
# Installing new version of config file /etc/java-11-openjdk/jfr/profile.jfc ...
# Installing new version of config file /etc/java-11-openjdk/security/java.security ...
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/jfr to provide /usr/bin/jfr (jfr) in auto mode
# Setting up librbd1 (12.2.12-0ubuntu0.18.04.4) ...
# Setting up r-cran-broom (0.5.4-1cran1ppabionic0) ...
# Setting up libegl-mesa0:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Setting up xserver-xorg-core-hwe-18.04 (2:1.20.5+git20191008-0ubuntu1~18.04.1) ...
# Setting up xserver-xorg-video-nvidia-440 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up openjdk-11-jre:amd64 (11.0.6+10-1ubuntu1~18.04.1) ...
# Setting up mesa-common-dev:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Setting up libgl1-mesa-dev:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Setting up nvidia-driver-440 (440.48.02-0ubuntu0~~18.04.1) ...
# Setting up libegl1-mesa-dev:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Setting up libgles2-mesa-dev:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-430 r-cran-zeallot
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.5).
# libavcodec-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavcodec-dev set to manually installed.
# libavformat-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libavformat-dev set to manually installed.
# libswscale-dev is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# libswscale-dev set to manually installed.
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-430 r-cran-zeallot
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-pango-1.0
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl libatk1.0-dev
#   libcairo-script-interpreter2 libcairo2-dev libfile-stripnondeterminism-perl
#   libgdk-pixbuf2.0-dev libmagic-mgc libmagic1 libmail-sendmail-perl
#   libpango1.0-dev libpangoxft-1.0-0 libpixman-1-dev libsigsegv2
#   libsys-hostname-long-perl libtimedate-perl libtool libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxml2-utils libxrandr-dev
#   m4 po-debconf x11proto-composite-dev x11proto-randr-dev
#   x11proto-xinerama-dev
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc dh-make dwz gettext-doc
#   libasprintf-dev libgettextpo-dev libcairo2-doc libgtk2.0-doc imagemagick
#   libpango1.0-doc libtool-doc gcj-jdk m4-doc libmail-box-perl
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-pango-1.0
#   intltool-debian libarchive-cpio-perl libarchive-zip-perl libatk1.0-dev
#   libcairo-script-interpreter2 libcairo2-dev libfile-stripnondeterminism-perl
#   libgdk-pixbuf2.0-dev libgtk2.0-dev libmagic-mgc libmagic1
#   libmail-sendmail-perl libpango1.0-dev libpangoxft-1.0-0 libpixman-1-dev
#   libsigsegv2 libsys-hostname-long-perl libtimedate-perl libtool
#   libxcb-shm0-dev libxcomposite-dev libxcursor-dev libxinerama-dev
#   libxml2-utils libxrandr-dev m4 po-debconf x11proto-composite-dev
#   x11proto-randr-dev x11proto-xinerama-dev
# 0 upgraded, 45 newly installed, 0 to remove and 8 not upgraded.
# Need to get 9,095 kB of archives.
# After this operation, 50.2 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.3 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.3 [68.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.3 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-atk-1.0 amd64 2.28.1-1 [17.8 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoxft-1.0-0 amd64 1.40.14-1ubuntu0.1 [15.0 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-pango-1.0 amd64 1.40.14-1ubuntu0.1 [21.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gtk-2.0 amd64 2.24.32-1ubuntu1 [172 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-dev amd64 2.28.1-1 [79.9 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango1.0-dev amd64 1.40.14-1ubuntu0.1 [288 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-composite-dev all 1:2018.4-4 [2,620 B]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite-dev amd64 1:0.4.4-2 [9,136 B]
# Get:42 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2-utils amd64 2.9.4+dfsg1-6.1ubuntu1.2 [35.8 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-dev amd64 2.24.32-1ubuntu1 [2,652 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Fetched 9,095 kB in 4s (2,554 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 145181 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.3_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.3) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../03-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../04-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../05-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../06-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../07-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../08-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../09-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../11-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../12-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../13-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../15-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../16-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../17-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../18-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../19-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../20-gir1.2-atk-1.0_2.28.1-1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../21-gir1.2-freedesktop_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../22-gir1.2-gdkpixbuf-2.0_2.36.11-2_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../23-libpangoxft-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../24-gir1.2-pango-1.0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-gtk-2.0.
# Preparing to unpack .../25-gir1.2-gtk-2.0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../26-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../27-libatk1.0-dev_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.28.1-1) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../28-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../29-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../30-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../31-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev.
# Preparing to unpack .../32-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Selecting previously unselected package libpango1.0-dev.
# Preparing to unpack .../33-libpango1.0-dev_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../34-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../35-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../36-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../37-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../38-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-composite-dev.
# Preparing to unpack .../39-x11proto-composite-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-composite-dev (1:2018.4-4) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../40-libxcomposite-dev_1%3a0.4.4-2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Selecting previously unselected package libxml2-utils.
# Preparing to unpack .../41-libxml2-utils_2.9.4+dfsg1-6.1ubuntu1.2_amd64.deb ...
# Unpacking libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.2) ...
# Selecting previously unselected package libgtk2.0-dev.
# Preparing to unpack .../42-libgtk2.0-dev_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../43-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../44-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.2) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up libatk1.0-dev:amd64 (2.28.1-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.3) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.3) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.3) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up libtool (2.4.6-2) ...
# Setting up po-debconf (1.0.20) ...
# Setting up libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Setting up dh-autoreconf (17) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !apt-get install libavcodec-dev libavformat-dev libswscale-d
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package libswscale-d

# %%
# !apt-get -y install cmake
# !which cmake

# !cmake --version
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-430 r-cran-zeallot
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# /usr/local/bin/cmake
# cmake version 3.12.0
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %%
# !apt-get install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-430 r-cran-zeallot
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %%
# !apt-get install vim
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-430 r-cran-zeallot
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   libgpm2 vim-common vim-runtime xxd
# Suggested packages:
#   gpm ctags vim-doc vim-scripts
# The following NEW packages will be installed:
#   libgpm2 vim vim-common vim-runtime xxd
# 0 upgraded, 5 newly installed, 0 to remove and 8 not upgraded.
# Need to get 6,721 kB of archives.
# After this operation, 32.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xxd amd64 2:8.0.1453-1ubuntu1.1 [49.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 vim-common all 2:8.0.1453-1ubuntu1.1 [70.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgpm2 amd64 1.20.7-5 [15.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 vim-runtime all 2:8.0.1453-1ubuntu1.1 [5,435 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 vim amd64 2:8.0.1453-1ubuntu1.1 [1,152 kB]
# Fetched 6,721 kB in 2s (3,809 kB/s)
# Selecting previously unselected package xxd.
# (Reading database ... 147160 files and directories currently installed.)
# Preparing to unpack .../xxd_2%3a8.0.1453-1ubuntu1.1_amd64.deb ...
# Unpacking xxd (2:8.0.1453-1ubuntu1.1) ...
# Selecting previously unselected package vim-common.
# Preparing to unpack .../vim-common_2%3a8.0.1453-1ubuntu1.1_all.deb ...
# Unpacking vim-common (2:8.0.1453-1ubuntu1.1) ...
# Selecting previously unselected package libgpm2:amd64.
# Preparing to unpack .../libgpm2_1.20.7-5_amd64.deb ...
# Unpacking libgpm2:amd64 (1.20.7-5) ...
# Selecting previously unselected package vim-runtime.
# Preparing to unpack .../vim-runtime_2%3a8.0.1453-1ubuntu1.1_all.deb ...
# Adding 'diversion of /usr/share/vim/vim80/doc/help.txt to /usr/share/vim/vim80/doc/help.txt.vim-tiny by vim-runtime'
# Adding 'diversion of /usr/share/vim/vim80/doc/tags to /usr/share/vim/vim80/doc/tags.vim-tiny by vim-runtime'
# Unpacking vim-runtime (2:8.0.1453-1ubuntu1.1) ...
# Selecting previously unselected package vim.
# Preparing to unpack .../vim_2%3a8.0.1453-1ubuntu1.1_amd64.deb ...
# Unpacking vim (2:8.0.1453-1ubuntu1.1) ...
# Setting up xxd (2:8.0.1453-1ubuntu1.1) ...
# Setting up libgpm2:amd64 (1.20.7-5) ...
# Setting up vim-common (2:8.0.1453-1ubuntu1.1) ...
# Setting up vim-runtime (2:8.0.1453-1ubuntu1.1) ...
# Setting up vim (2:8.0.1453-1ubuntu1.1) ...
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vim (vim) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vimdiff (vimdiff) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/rvim (rvim) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/rview (rview) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/vi (vi) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/view (view) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/ex (ex) in auto mode
# update-alternatives: using /usr/bin/vim.basic to provide /usr/bin/editor (editor) in auto mode
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
ls
# Out:
# 3rdparty/     CMakeLists.txt          image_yolov2.sh*        README.md
# appveyor.yml  DarknetConfig.cmake.in  image_yolov3.sh*        scripts/
# build/        darknet.py              include/                src/
# build.ps1*    darknet_video.py        json_mjpeg_streams.sh*  test.txt
# build.sh*     data/                   LICENSE                 train.txt
# cfg/          data_for_colab/         Makefile                video_v2.sh*
# cmake/        data_for_colab.zip      net_cam_v3.sh*          video_yolov3.sh*

# %%
#Now let's get some YOLOv3 weights from the official site
# !ls
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# 3rdparty      CMakeLists.txt	      image_yolov2.sh	     README.md
# appveyor.yml  DarknetConfig.cmake.in  image_yolov3.sh	     scripts
# build	      darknet.py	      include		     src
# build.ps1     darknet_video.py	      json_mjpeg_streams.sh  test.txt
# build.sh      data		      LICENSE		     train.txt
# cfg	      data_for_colab	      Makefile		     video_v2.sh
# cmake	      data_for_colab.zip      net_cam_v3.sh	     video_yolov3.sh
# --2020-01-30 06:54:31--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  37.3MB/s    in 5.4s
#
# 2020-01-30 06:54:37 (43.9 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
#No here we're modifying the makefile to set OPENCV and GPU to 1
# !ls
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       test.txt
# appveyor.yml	darknet.py		json_mjpeg_streams.sh  train.txt
# build		darknet_video.py	LICENSE		       video_v2.sh
# build.ps1	data			Makefile	       video_yolov3.sh
# build.sh	data_for_colab		net_cam_v3.sh	       yolov3.weights
# cfg		data_for_colab.zip	README.md
# cmake		image_yolov2.sh		scripts
# CMakeLists.txt	image_yolov3.sh		src

# %%
# !ls
# %cd ../
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       test.txt
# appveyor.yml	darknet.py		json_mjpeg_streams.sh  train.txt
# build		darknet_video.py	LICENSE		       video_v2.sh
# build.ps1	data			Makefile	       video_yolov3.sh
# build.sh	data_for_colab		net_cam_v3.sh	       yolov3.weights
# cfg		data_for_colab.zip	README.md
# cmake		image_yolov2.sh		scripts
# CMakeLists.txt	image_yolov3.sh		src
# /content
# darknet  drive	sample_data

# %%
# !apt install g++-5
# !apt install gcc-5

# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 10
# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 20
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 10
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 20
# !update-alternatives --install /usr/bin/cc cc /usr/bin/gcc 30
# !update-alternatives --set cc /usr/bin/gcc
# !update-alternatives --install /usr/bin/c++ c++ /usr/bin/g++ 30
# !update-alternatives --set c++ /usr/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-430 r-cran-zeallot
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   cpp-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 8 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5-base amd64 5.5.0-12ubuntu1 [17.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libisl15 amd64 0.18-4 [548 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cpp-5 amd64 5.5.0-12ubuntu1 [7,785 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libasan2 amd64 5.5.0-12ubuntu1 [264 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libmpx0 amd64 5.5.0-12ubuntu1 [9,888 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgcc-5-dev amd64 5.5.0-12ubuntu1 [2,224 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 gcc-5 amd64 5.5.0-12ubuntu1 [8,357 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libstdc++-5-dev amd64 5.5.0-12ubuntu1 [1,415 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 g++-5 amd64 5.5.0-12ubuntu1 [8,450 kB]
# Fetched 29.1 MB in 2s (13.9 MB/s)
# Selecting previously unselected package gcc-5-base:amd64.
# (Reading database ... 149003 files and directories currently installed.)
# Preparing to unpack .../0-gcc-5-base_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libisl15:amd64.
# Preparing to unpack .../1-libisl15_0.18-4_amd64.deb ...
# Unpacking libisl15:amd64 (0.18-4) ...
# Selecting previously unselected package cpp-5.
# Preparing to unpack .../2-cpp-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking cpp-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libasan2:amd64.
# Preparing to unpack .../3-libasan2_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libasan2:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libmpx0:amd64.
# Preparing to unpack .../4-libmpx0_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libgcc-5-dev:amd64.
# Preparing to unpack .../5-libgcc-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package gcc-5.
# Preparing to unpack .../6-gcc-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking gcc-5 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package libstdc++-5-dev:amd64.
# Preparing to unpack .../7-libstdc++-5-dev_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Selecting previously unselected package g++-5.
# Preparing to unpack .../8-g++-5_5.5.0-12ubuntu1_amd64.deb ...
# Unpacking g++-5 (5.5.0-12ubuntu1) ...
# Setting up libisl15:amd64 (0.18-4) ...
# Setting up gcc-5-base:amd64 (5.5.0-12ubuntu1) ...
# Setting up libmpx0:amd64 (5.5.0-12ubuntu1) ...
# Setting up libasan2:amd64 (5.5.0-12ubuntu1) ...
# Setting up libgcc-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up cpp-5 (5.5.0-12ubuntu1) ...
# Setting up libstdc++-5-dev:amd64 (5.5.0-12ubuntu1) ...
# Setting up gcc-5 (5.5.0-12ubuntu1) ...
# Setting up g++-5 (5.5.0-12ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# gcc-5 is already the newest version (5.5.0-12ubuntu1).
# gcc-5 set to manually installed.
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-430 r-cran-zeallot
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# update-alternatives: using /usr/bin/gcc-5 to provide /usr/bin/gcc (gcc) in auto mode
# update-alternatives: using /usr/bin/g++-5 to provide /usr/bin/g++ (g++) in auto mode

# %%
#Now, here's a bunch of code that takes the longest to execute here but
#It's about installing CUDA and using the beautiful Tesla K80 GPU, so that
#Will worth it

# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !apt-get update -qq

#Here were are installing compilers and creating some links
# !apt-get install cuda -y -qq #gcc-5 g++-5 
#!ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
#!ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# !apt update
# !apt upgrade
# !apt install cuda-8.0 -y
# Out:
# 8 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2020-01-30 06:57:57--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.162.216
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.162.216|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?nmBZC4_d9YfdrS4KvidzXfUMlfF7zWZlW06Fhtaztnvd8M4SkzCDKv9fx2Pa-xEuzaP0SaOYycN4OXdtKADR8G0Mkb8qUVK_9vIwz9dhwJu5v77uru25SwfQCJijSbeB2ZadAXFpQkFKFAq1fVe1fjoiI76f8rsFI1mREMZBYy0avUQEem7PHr3e3w2awVhSOup68YiHJUtXXvUqizYg_2tOgA [following]
# --2020-01-30 06:57:57--  https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?nmBZC4_d9YfdrS4KvidzXfUMlfF7zWZlW06Fhtaztnvd8M4SkzCDKv9fx2Pa-xEuzaP0SaOYycN4OXdtKADR8G0Mkb8qUVK_9vIwz9dhwJu5v77uru25SwfQCJijSbeB2ZadAXFpQkFKFAq1fVe1fjoiI76f8rsFI1mREMZBYy0avUQEem7PHr3e3w2awVhSOup68YiHJUtXXvUqizYg_2tOgA
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 192.229.211.70, 2606:2800:21f:3aa:dcf:37b:1ed6:1fb
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|192.229.211.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1913589814 (1.8G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’
#
# cuda-repo-ubuntu160 100%[===================>]   1.78G  20.1MB/s    in 20s
#
# 2020-01-30 06:58:17 (92.8 MB/s) - ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’ saved [1913589814/1913589814]
#
# Selecting previously unselected package cuda-repo-ubuntu1604-8-0-local-ga2.
# (Reading database ... 150003 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb ...
# Unpacking cuda-repo-ubuntu1604-8-0-local-ga2 (8.0.61-1) ...
# Setting up cuda-repo-ubuntu1604-8-0-local-ga2 (8.0.61-1) ...
# Warning: The postinst maintainerscript of the package cuda-repo-ubuntu1604-8-0-local-ga2
# Warning: seems to use apt-key (provided by apt) without depending on gnupg or gnupg2.
# Warning: This will BREAK in the future and should be fixed by the package maintainer(s).
# Note: Check first if apt-key functionality is needed at all - it probably isn't!
# Warning: apt-key should not be used in scripts (called from postinst maintainerscript of the package cuda-repo-ubuntu1604-8-0-local-ga2)
# OK
# Extracting templates from packages: 100%
# Selecting previously unselected package cuda-license-10-2.
# (Reading database ... 150097 files and directories currently installed.)
# Preparing to unpack .../00-cuda-license-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-license-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-misc-headers-10-2.
# Preparing to unpack .../01-cuda-misc-headers-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-misc-headers-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvcc-10-2.
# Preparing to unpack .../02-cuda-nvcc-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvcc-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cuobjdump-10-2.
# Preparing to unpack .../03-cuda-cuobjdump-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cuobjdump-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvprune-10-2.
# Preparing to unpack .../04-cuda-nvprune-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvprune-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-compiler-10-2.
# Preparing to unpack .../05-cuda-compiler-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-compiler-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvdisasm-10-2.
# Preparing to unpack .../06-cuda-nvdisasm-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvdisasm-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-gdb-10-2.
# Preparing to unpack .../07-cuda-gdb-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-gdb-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvprof-10-2.
# Preparing to unpack .../08-cuda-nvprof-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvprof-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-sanitizer-api-10-2.
# Preparing to unpack .../09-cuda-sanitizer-api-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-sanitizer-api-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-memcheck-10-2.
# Preparing to unpack .../10-cuda-memcheck-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-memcheck-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cudart-10-2.
# Preparing to unpack .../11-cuda-cudart-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cudart-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-driver-dev-10-2.
# Preparing to unpack .../12-cuda-driver-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-driver-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cudart-dev-10-2.
# Preparing to unpack .../13-cuda-cudart-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cudart-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cupti-10-2.
# Preparing to unpack .../14-cuda-cupti-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cupti-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cupti-dev-10-2.
# Preparing to unpack .../15-cuda-cupti-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cupti-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvtx-10-2.
# Preparing to unpack .../16-cuda-nvtx-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvtx-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-command-line-tools-10-2.
# Preparing to unpack .../17-cuda-command-line-tools-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-command-line-tools-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nsight-10-2.
# Preparing to unpack .../18-cuda-nsight-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nsight-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvvp-10-2.
# Preparing to unpack .../19-cuda-nvvp-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvvp-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvrtc-10-2.
# Preparing to unpack .../20-cuda-nvrtc-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-10-2.
# Preparing to unpack .../21-cuda-nvrtc-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusolver-10-2.
# Preparing to unpack .../22-cuda-cusolver-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusolver-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusolver-dev-10-2.
# Preparing to unpack .../23-cuda-cusolver-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-10-2 (10.2.89-1) ...
# Preparing to unpack .../24-libcublas10_10.2.2.89-1_amd64.deb ...
# Unpacking libcublas10 (10.2.2.89-1) over (10.2.1.243-1) ...
# Preparing to unpack .../25-libcublas-dev_10.2.2.89-1_amd64.deb ...
# Unpacking libcublas-dev (10.2.2.89-1) over (10.2.1.243-1) ...
# Selecting previously unselected package cuda-cufft-10-2.
# Preparing to unpack .../26-cuda-cufft-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cufft-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cufft-dev-10-2.
# Preparing to unpack .../27-cuda-cufft-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cufft-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-curand-10-2.
# Preparing to unpack .../28-cuda-curand-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-curand-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-curand-dev-10-2.
# Preparing to unpack .../29-cuda-curand-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-curand-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusparse-10-2.
# Preparing to unpack .../30-cuda-cusparse-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusparse-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-cusparse-dev-10-2.
# Preparing to unpack .../31-cuda-cusparse-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-npp-10-2.
# Preparing to unpack .../32-cuda-npp-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-npp-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-npp-dev-10-2.
# Preparing to unpack .../33-cuda-npp-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-npp-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvml-dev-10-2.
# Preparing to unpack .../34-cuda-nvml-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvml-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvjpeg-10-2.
# Preparing to unpack .../35-cuda-nvjpeg-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvjpeg-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvjpeg-dev-10-2.
# Preparing to unpack .../36-cuda-nvjpeg-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvjpeg-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nsight-compute-10-2.
# Preparing to unpack .../37-cuda-nsight-compute-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nsight-compute-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nsight-systems-10-2.
# Preparing to unpack .../38-cuda-nsight-systems-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nsight-systems-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvgraph-10-2.
# Preparing to unpack .../39-cuda-nvgraph-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvgraph-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-10-2.
# Preparing to unpack .../40-cuda-nvgraph-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-visual-tools-10-2.
# Preparing to unpack .../41-cuda-visual-tools-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-visual-tools-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-tools-10-2.
# Preparing to unpack .../42-cuda-tools-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-tools-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-samples-10-2.
# Preparing to unpack .../43-cuda-samples-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-samples-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-documentation-10-2.
# Preparing to unpack .../44-cuda-documentation-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-documentation-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-libraries-dev-10-2.
# Preparing to unpack .../45-cuda-libraries-dev-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-libraries-dev-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-libraries-10-2.
# Preparing to unpack .../46-cuda-libraries-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-libraries-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-toolkit-10-2.
# Preparing to unpack .../47-cuda-toolkit-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-toolkit-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-runtime-10-2.
# Preparing to unpack .../48-cuda-runtime-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-runtime-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-demo-suite-10-2.
# Preparing to unpack .../49-cuda-demo-suite-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-demo-suite-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda-10-2.
# Preparing to unpack .../50-cuda-10-2_10.2.89-1_amd64.deb ...
# Unpacking cuda-10-2 (10.2.89-1) ...
# Selecting previously unselected package cuda.
# Preparing to unpack .../51-cuda_10.2.89-1_amd64.deb ...
# Unpacking cuda (10.2.89-1) ...
# Setting up cuda-license-10-2 (10.2.89-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-10.2/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up cuda-nvgraph-10-2 (10.2.89-1) ...
# Setting up cuda-nvprune-10-2 (10.2.89-1) ...
# Setting up cuda-nvrtc-10-2 (10.2.89-1) ...
# Setting up cuda-nvtx-10-2 (10.2.89-1) ...
# Setting up cuda-nvjpeg-10-2 (10.2.89-1) ...
# Setting up libcublas10 (10.2.2.89-1) ...
# Setting up libcublas-dev (10.2.2.89-1) ...
# Setting up cuda-cufft-10-2 (10.2.89-1) ...
# Setting up cuda-nsight-compute-10-2 (10.2.89-1) ...
# Setting up cuda-cusparse-10-2 (10.2.89-1) ...
# Setting up cuda-cuobjdump-10-2 (10.2.89-1) ...
# Setting up cuda-sanitizer-api-10-2 (10.2.89-1) ...
# Setting up cuda-nvjpeg-dev-10-2 (10.2.89-1) ...
# Setting up cuda-cusolver-10-2 (10.2.89-1) ...
# Setting up cuda-misc-headers-10-2 (10.2.89-1) ...
# Setting up cuda-nvvp-10-2 (10.2.89-1) ...
# Setting up cuda-curand-10-2 (10.2.89-1) ...
# Setting up cuda-cudart-10-2 (10.2.89-1) ...
# Setting up cuda-npp-10-2 (10.2.89-1) ...
# Setting up cuda-cufft-dev-10-2 (10.2.89-1) ...
# Setting up cuda-libraries-10-2 (10.2.89-1) ...
# Setting up cuda-memcheck-10-2 (10.2.89-1) ...
# Setting up cuda-nvrtc-dev-10-2 (10.2.89-1) ...
# Setting up cuda-driver-dev-10-2 (10.2.89-1) ...
# Setting up cuda-npp-dev-10-2 (10.2.89-1) ...
# Setting up cuda-nsight-systems-10-2 (10.2.89-1) ...
# Setting up cuda-nsight-10-2 (10.2.89-1) ...
# Setting up cuda-nvdisasm-10-2 (10.2.89-1) ...
# Setting up cuda-nvml-dev-10-2 (10.2.89-1) ...
# Setting up cuda-nvgraph-dev-10-2 (10.2.89-1) ...
# Setting up cuda-nvcc-10-2 (10.2.89-1) ...
# Setting up cuda-nvprof-10-2 (10.2.89-1) ...
# Setting up cuda-cusparse-dev-10-2 (10.2.89-1) ...
# Setting up cuda-compiler-10-2 (10.2.89-1) ...
# Setting up cuda-runtime-10-2 (10.2.89-1) ...
# Setting up cuda-curand-dev-10-2 (10.2.89-1) ...
# Setting up cuda-cusolver-dev-10-2 (10.2.89-1) ...
# Setting up cuda-demo-suite-10-2 (10.2.89-1) ...
# Setting up cuda-gdb-10-2 (10.2.89-1) ...
# Setting up cuda-cudart-dev-10-2 (10.2.89-1) ...
# Setting up cuda-libraries-dev-10-2 (10.2.89-1) ...
# Setting up cuda-visual-tools-10-2 (10.2.89-1) ...
# Setting up cuda-samples-10-2 (10.2.89-1) ...
# Setting up cuda-cupti-10-2 (10.2.89-1) ...
# Setting up cuda-documentation-10-2 (10.2.89-1) ...
# Setting up cuda-cupti-dev-10-2 (10.2.89-1) ...
# Setting up cuda-command-line-tools-10-2 (10.2.89-1) ...
# Setting up cuda-tools-10-2 (10.2.89-1) ...
# Setting up cuda-toolkit-10-2 (10.2.89-1) ...
# Setting up cuda-10-2 (10.2.89-1) ...
# Setting up cuda (10.2.89-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Get:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Ign:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Hit:3 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Ign:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:7 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:13 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Fetched 74.6 kB in 2s (45.8 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 6 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Calculating upgrade... Done
# The following packages were automatically installed and are no longer required:
#   libllvm8 libnvidia-common-430 linux-headers-4.15.0-72
#   linux-headers-4.15.0-72-generic r-cran-zeallot
# Use 'apt autoremove' to remove them.
# The following NEW packages will be installed:
#   libllvm9 linux-headers-4.15.0-76 linux-headers-4.15.0-76-generic
# The following packages have been kept back:
#   libcudnn7 libcudnn7-dev libnccl-dev libnccl2
# The following packages will be upgraded:
#   libgl1-mesa-dri linux-headers-generic
# 2 upgraded, 3 newly installed, 0 to remove and 4 not upgraded.
# Need to get 35.6 MB of archives.
# After this operation, 242 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libllvm9 amd64 1:9-2~ubuntu18.04.1 [14.8 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dri amd64 19.2.1-1ubuntu1~18.04.1 [8,810 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-76 all 4.15.0-76.86 [10.9 MB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-4.15.0-76-generic amd64 4.15.0-76.86 [1,106 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 linux-headers-generic amd64 4.15.0.76.78 [2,348 B]
# Fetched 35.6 MB in 2s (16.6 MB/s)
# Selecting previously unselected package libllvm9:amd64.
# (Reading database ... 162513 files and directories currently installed.)
# Preparing to unpack .../libllvm9_1%3a9-2~ubuntu18.04.1_amd64.deb ...
# Unpacking libllvm9:amd64 (1:9-2~ubuntu18.04.1) ...
# Preparing to unpack .../libgl1-mesa-dri_19.2.1-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgl1-mesa-dri:amd64 (19.2.1-1ubuntu1~18.04.1) over (19.0.8-0ubuntu0~18.04.3) ...
# Selecting previously unselected package linux-headers-4.15.0-76.
# Preparing to unpack .../linux-headers-4.15.0-76_4.15.0-76.86_all.deb ...
# Unpacking linux-headers-4.15.0-76 (4.15.0-76.86) ...
# Selecting previously unselected package linux-headers-4.15.0-76-generic.
# Preparing to unpack .../linux-headers-4.15.0-76-generic_4.15.0-76.86_amd64.deb ...
# Unpacking linux-headers-4.15.0-76-generic (4.15.0-76.86) ...
# Preparing to unpack .../linux-headers-generic_4.15.0.76.78_amd64.deb ...
# Unpacking linux-headers-generic (4.15.0.76.78) over (4.15.0.72.74) ...
# Setting up libllvm9:amd64 (1:9-2~ubuntu18.04.1) ...
# Setting up linux-headers-4.15.0-76 (4.15.0-76.86) ...
# Setting up linux-headers-4.15.0-76-generic (4.15.0-76.86) ...
# /etc/kernel/header_postinst.d/dkms:
#  * dkms: running auto installation service for kernel 4.15.0-76-generic
#
# Kernel preparation unnecessary for this kernel.  Skipping...
#
# Building module:
# cleaning build area...(bad exit status: 2)
# unset ARCH; [ ! -h /usr/bin/cc ] && export CC=/usr/bin/gcc; env NV_VERBOSE=1 'make' -j2 NV_EXCLUDE_BUILD_MODULES='' KERNEL_UNAME=4.15.0-76-generic IGNORE_XEN_PRESENCE=1 IGNORE_CC_MISMATCH=1 SYSSRC=/lib/modules/4.15.0-76-generic/build LD=/usr/bin/ld.bfd modules...........................
# cleaning build area...(bad exit status: 2)
#
# DKMS: build completed.
#
# nvidia.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-76-generic/updates/dkms/
#
# nvidia-modeset.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-76-generic/updates/dkms/
#
# nvidia-drm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-76-generic/updates/dkms/
#
# nvidia-uvm.ko:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.15.0-76-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
#    ...done.
# Setting up libgl1-mesa-dri:amd64 (19.2.1-1ubuntu1~18.04.1) ...
# Setting up linux-headers-generic (4.15.0.76.78) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'cuda-8-0' for regex 'cuda-8.0'
# Note, selecting 'libcuda-8.0-1' for regex 'cuda-8.0'
# The following packages were automatically installed and are no longer required:
#   libllvm8 libnvidia-common-430 linux-headers-4.15.0-72
#   linux-headers-4.15.0-72-generic r-cran-zeallot
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   cuda-command-line-tools-8-0 cuda-core-8-0 cuda-cublas-8-0
#   cuda-cublas-dev-8-0 cuda-cudart-8-0 cuda-cudart-dev-8-0 cuda-cufft-8-0
#   cuda-cufft-dev-8-0 cuda-curand-8-0 cuda-curand-dev-8-0 cuda-cusolver-8-0
#   cuda-cusolver-dev-8-0 cuda-cusparse-8-0 cuda-cusparse-dev-8-0
#   cuda-demo-suite-8-0 cuda-documentation-8-0 cuda-driver-dev-8-0
#   cuda-license-8-0 cuda-misc-headers-8-0 cuda-npp-8-0 cuda-npp-dev-8-0
#   cuda-nvgraph-8-0 cuda-nvgraph-dev-8-0 cuda-nvml-dev-8-0 cuda-nvrtc-8-0
#   cuda-nvrtc-dev-8-0 cuda-runtime-8-0 cuda-samples-8-0 cuda-toolkit-8-0
#   cuda-visual-tools-8-0
# The following NEW packages will be installed:
#   cuda-8-0 cuda-command-line-tools-8-0 cuda-core-8-0 cuda-cublas-8-0
#   cuda-cublas-dev-8-0 cuda-cudart-8-0 cuda-cudart-dev-8-0 cuda-cufft-8-0
#   cuda-cufft-dev-8-0 cuda-curand-8-0 cuda-curand-dev-8-0 cuda-cusolver-8-0
#   cuda-cusolver-dev-8-0 cuda-cusparse-8-0 cuda-cusparse-dev-8-0
#   cuda-demo-suite-8-0 cuda-documentation-8-0 cuda-driver-dev-8-0
#   cuda-license-8-0 cuda-misc-headers-8-0 cuda-npp-8-0 cuda-npp-dev-8-0
#   cuda-nvgraph-8-0 cuda-nvgraph-dev-8-0 cuda-nvml-dev-8-0 cuda-nvrtc-8-0
#   cuda-nvrtc-dev-8-0 cuda-runtime-8-0 cuda-samples-8-0 cuda-toolkit-8-0
#   cuda-visual-tools-8-0
# 0 upgraded, 31 newly installed, 0 to remove and 4 not upgraded.
# Need to get 0 B/1,312 MB of archives.
# After this operation, 2,079 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-8-0-local-ga2  cuda-license-8-0 8.0.61-1 [27.6 kB]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  cuda-misc-headers-8-0 8.0.61-1 [1,077 kB]
# Get:3 file:/var/cuda-repo-8-0-local-ga2  cuda-core-8-0 8.0.61-1 [20.0 MB]
# Get:4 file:/var/cuda-repo-8-0-local-ga2  cuda-cudart-8-0 8.0.61-1 [135 kB]
# Get:5 file:/var/cuda-repo-8-0-local-ga2  cuda-driver-dev-8-0 8.0.61-1 [14.1 kB]
# Get:6 file:/var/cuda-repo-8-0-local-ga2  cuda-cudart-dev-8-0 8.0.61-1 [1,071 kB]
# Get:7 file:/var/cuda-repo-8-0-local-ga2  cuda-command-line-tools-8-0 8.0.61-1 [26.1 MB]
# Get:8 file:/var/cuda-repo-8-0-local-ga2  cuda-nvrtc-8-0 8.0.61-1 [9,585 kB]
# Get:9 file:/var/cuda-repo-8-0-local-ga2  cuda-nvrtc-dev-8-0 8.0.61-1 [10.8 kB]
# Get:10 file:/var/cuda-repo-8-0-local-ga2  cuda-cusolver-8-0 8.0.61-1 [29.3 MB]
# Get:11 file:/var/cuda-repo-8-0-local-ga2  cuda-cusolver-dev-8-0 8.0.61-1 [6,816 kB]
# Get:12 file:/var/cuda-repo-8-0-local-ga2  cuda-cublas-8-0 8.0.61-1 [27.2 MB]
# Get:13 file:/var/cuda-repo-8-0-local-ga2  cuda-cublas-dev-8-0 8.0.61-1 [57.4 MB]
# Get:14 file:/var/cuda-repo-8-0-local-ga2  cuda-cufft-8-0 8.0.61-1 [117 MB]
# Get:15 file:/var/cuda-repo-8-0-local-ga2  cuda-cufft-dev-8-0 8.0.61-1 [94.8 MB]
# Get:16 file:/var/cuda-repo-8-0-local-ga2  cuda-curand-8-0 8.0.61-1 [43.7 MB]
# Get:17 file:/var/cuda-repo-8-0-local-ga2  cuda-curand-dev-8-0 8.0.61-1 [67.7 MB]
# Get:18 file:/var/cuda-repo-8-0-local-ga2  cuda-cusparse-8-0 8.0.61-1 [28.8 MB]
# Get:19 file:/var/cuda-repo-8-0-local-ga2  cuda-cusparse-dev-8-0 8.0.61-1 [29.6 MB]
# Get:20 file:/var/cuda-repo-8-0-local-ga2  cuda-npp-8-0 8.0.61-1 [157 MB]
# Get:21 file:/var/cuda-repo-8-0-local-ga2  cuda-npp-dev-8-0 8.0.61-1 [82.3 MB]
# Get:22 file:/var/cuda-repo-8-0-local-ga2  cuda-samples-8-0 8.0.61-1 [101 MB]
# Get:23 file:/var/cuda-repo-8-0-local-ga2  cuda-documentation-8-0 8.0.61-1 [113 MB]
# Get:24 file:/var/cuda-repo-8-0-local-ga2  cuda-nvml-dev-8-0 8.0.61-1 [48.4 kB]
# Get:25 file:/var/cuda-repo-8-0-local-ga2  cuda-nvgraph-8-0 8.0.61-1 [2,948 kB]
# Get:26 file:/var/cuda-repo-8-0-local-ga2  cuda-nvgraph-dev-8-0 8.0.61-1 [3,028 kB]
# Get:27 file:/var/cuda-repo-8-0-local-ga2  cuda-visual-tools-8-0 8.0.61-1 [286 MB]
# Get:28 file:/var/cuda-repo-8-0-local-ga2  cuda-toolkit-8-0 8.0.61-1 [2,892 B]
# Get:29 file:/var/cuda-repo-8-0-local-ga2  cuda-runtime-8-0 8.0.61-1 [2,574 B]
# Get:30 file:/var/cuda-repo-8-0-local-ga2  cuda-demo-suite-8-0 8.0.61-1 [4,988 kB]
# Get:31 file:/var/cuda-repo-8-0-local-ga2  cuda-8-0 8.0.61-1 [2,556 B]
# Extracting templates from packages: 100%
# Selecting previously unselected package cuda-license-8-0.
# (Reading database ... 191805 files and directories currently installed.)
# Preparing to unpack .../00-cuda-license-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-license-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-misc-headers-8-0.
# Preparing to unpack .../01-cuda-misc-headers-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-misc-headers-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-core-8-0.
# Preparing to unpack .../02-cuda-core-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-core-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cudart-8-0.
# Preparing to unpack .../03-cuda-cudart-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cudart-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-driver-dev-8-0.
# Preparing to unpack .../04-cuda-driver-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-driver-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cudart-dev-8-0.
# Preparing to unpack .../05-cuda-cudart-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cudart-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-command-line-tools-8-0.
# Preparing to unpack .../06-cuda-command-line-tools-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-command-line-tools-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvrtc-8-0.
# Preparing to unpack .../07-cuda-nvrtc-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-8-0.
# Preparing to unpack .../08-cuda-nvrtc-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusolver-8-0.
# Preparing to unpack .../09-cuda-cusolver-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusolver-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusolver-dev-8-0.
# Preparing to unpack .../10-cuda-cusolver-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusolver-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cublas-8-0.
# Preparing to unpack .../11-cuda-cublas-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cublas-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cublas-dev-8-0.
# Preparing to unpack .../12-cuda-cublas-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cublas-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cufft-8-0.
# Preparing to unpack .../13-cuda-cufft-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cufft-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cufft-dev-8-0.
# Preparing to unpack .../14-cuda-cufft-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cufft-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-curand-8-0.
# Preparing to unpack .../15-cuda-curand-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-curand-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-curand-dev-8-0.
# Preparing to unpack .../16-cuda-curand-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-curand-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusparse-8-0.
# Preparing to unpack .../17-cuda-cusparse-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusparse-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-cusparse-dev-8-0.
# Preparing to unpack .../18-cuda-cusparse-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-cusparse-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-npp-8-0.
# Preparing to unpack .../19-cuda-npp-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-npp-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-npp-dev-8-0.
# Preparing to unpack .../20-cuda-npp-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-npp-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-samples-8-0.
# Preparing to unpack .../21-cuda-samples-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-samples-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-documentation-8-0.
# Preparing to unpack .../22-cuda-documentation-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-documentation-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvml-dev-8-0.
# Preparing to unpack .../23-cuda-nvml-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvml-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvgraph-8-0.
# Preparing to unpack .../24-cuda-nvgraph-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvgraph-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-nvgraph-dev-8-0.
# Preparing to unpack .../25-cuda-nvgraph-dev-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-nvgraph-dev-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-visual-tools-8-0.
# Preparing to unpack .../26-cuda-visual-tools-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-visual-tools-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-toolkit-8-0.
# Preparing to unpack .../27-cuda-toolkit-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-toolkit-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-runtime-8-0.
# Preparing to unpack .../28-cuda-runtime-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-runtime-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-demo-suite-8-0.
# Preparing to unpack .../29-cuda-demo-suite-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-demo-suite-8-0 (8.0.61-1) ...
# Selecting previously unselected package cuda-8-0.
# Preparing to unpack .../30-cuda-8-0_8.0.61-1_amd64.deb ...
# Unpacking cuda-8-0 (8.0.61-1) ...
# Setting up cuda-license-8-0 (8.0.61-1) ...
# *** LICENSE AGREEMENT ***
# By using this software you agree to fully comply with the terms and
# conditions of the EULA (End User License Agreement). The EULA is located
# at /usr/local/cuda-8.0/doc/EULA.txt. The EULA can also be found at
# http://docs.nvidia.com/cuda/eula/index.html. If you do not agree to the
# terms and conditions of the EULA, do not use the software.
#
# Setting up cuda-nvgraph-8-0 (8.0.61-1) ...
# Setting up cuda-cufft-8-0 (8.0.61-1) ...
# Setting up cuda-npp-8-0 (8.0.61-1) ...
# Setting up cuda-nvgraph-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cudart-8-0 (8.0.61-1) ...
# Setting up cuda-driver-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cusolver-8-0 (8.0.61-1) ...
# Setting up cuda-nvml-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cufft-dev-8-0 (8.0.61-1) ...
# Setting up cuda-misc-headers-8-0 (8.0.61-1) ...
# Setting up cuda-cusparse-8-0 (8.0.61-1) ...
# Setting up cuda-nvrtc-8-0 (8.0.61-1) ...
# Setting up cuda-nvrtc-dev-8-0 (8.0.61-1) ...
# Setting up cuda-curand-8-0 (8.0.61-1) ...
# Setting up cuda-cublas-8-0 (8.0.61-1) ...
# Setting up cuda-cusolver-dev-8-0 (8.0.61-1) ...
# Setting up cuda-core-8-0 (8.0.61-1) ...
# Setting up cuda-curand-dev-8-0 (8.0.61-1) ...
# Setting up cuda-npp-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cudart-dev-8-0 (8.0.61-1) ...
# Setting up cuda-cublas-dev-8-0 (8.0.61-1) ...
# Setting up cuda-runtime-8-0 (8.0.61-1) ...
# Setting up cuda-cusparse-dev-8-0 (8.0.61-1) ...
# Setting up cuda-command-line-tools-8-0 (8.0.61-1) ...
# Setting up cuda-demo-suite-8-0 (8.0.61-1) ...
# Setting up cuda-samples-8-0 (8.0.61-1) ...
# Setting up cuda-visual-tools-8-0 (8.0.61-1) ...
# Setting up cuda-documentation-8-0 (8.0.61-1) ...
# Setting up cuda-toolkit-8-0 (8.0.61-1) ...
# Setting up cuda-8-0 (8.0.61-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
#Now let's see whether the GPU is here and CUDA was successfully installed!
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)

print("'sup!'")

# !/usr/local/cuda/bin/nvcc --version
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# /device:GPU:0
# 'sup!'
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %%
# %cd content/
# Out:
# [Errno 2] No such file or directory: 'content/'
# /content

# %%
ls
# Out:
# cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb  drive/
# darknet/                                               sample_data/

# %%
# %cd darknet
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:909:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ./src/image_opencv.cpp: At global scope:
# ./src/image_opencv.cpp:427:14: warning: ‘float get_pixel(image, int, int, int)’ defined but not used [-Wunused-function]
#  static float get_pixel(image m, int x, int y, int c)
#               ^
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:576:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#  ^
# ./src/http_stream.cpp:71:0: note: this is the location of the previous definition
#  #define INVALID_SOCKET -1
#  ^
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:247:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:508:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2039:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^
# ./src/gemm.c:2038:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:264:16: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                 ^
# ./src/dark_cuda.c:264:16: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
# ./src/dark_cuda.c:264:16: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
# ./src/dark_cuda.c:274:24: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                         ^
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:295:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                     ^
# ./src/dark_cuda.c:310:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                     ^
# ./src/dark_cuda.c:316:20: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                     ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1200:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:73:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^
# ./src/activations.c:73:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:73:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:73:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:73:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:281:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^
# ./src/activations.c:281:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:205:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1120:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:976:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:591:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1436:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:886:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^
# ./src/box.c:885:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:481:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:592:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^
# ./src/detector.c:590:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1211:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^
# ./src/detector.c:1210:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:808:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1238:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^
# ./src/classifier.c:1238:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:54:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:59:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:66:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:93:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c:102:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:357:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:69:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c:76:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:108:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c:117:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:91:0,
#                  from include/darknet.h:39,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:3316:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^
# ./src/gaussian_yolo_layer.c: In function ‘forward_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:451:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#                   ^
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#       ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# ./src/blas_kernels.cu(846): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(869): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1459): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(846): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(869): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1459): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(846): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(869): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1459): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(846): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(869): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1459): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(846): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(869): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1459): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(846): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(869): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1459): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:869:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# ./src/dropout_layer_kernels.cu(57): warning: variable "x" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(57): warning: variable "x" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(57): warning: variable "x" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(57): warning: variable "x" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(57): warning: variable "x" was declared but never referenced
#
# ./src/dropout_layer_kernels.cu(57): warning: variable "x" was declared but never referenced
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -lstdc++

# %%
# !ls
#Now, let's see if everything works by running it on a test image
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg
# Out:
# 3rdparty	darknet			include		       src
# appveyor.yml	DarknetConfig.cmake.in	json_mjpeg_streams.sh  test.txt
# backup		darknet.py		LICENSE		       train.txt
# build		darknet_video.py	Makefile	       video_v2.sh
# build.ps1	data			net_cam_v3.sh	       video_yolov3.sh
# build.sh	data_for_colab		obj		       yolov3.weights
# cfg		data_for_colab.zip	README.md
# cmake		image_yolov2.sh		results
# CMakeLists.txt	image_yolov3.sh		scripts
#  CUDA-version: 8000 (10010)
#  Warning: CUDA-version is lower than Driver-version!
# , GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv    255       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 255 0.088 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv    255       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 255 0.177 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv    255       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 255 0.353 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.879
#  Allocate additional workspace_size = 49.84 MB
# Loading weights from yolov3.weights...
#  seen 64, trained: 32013 K-images (500 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# data/person.jpg: Predicted in 59821.332000 milli-seconds.
# dog: 99%
# person: 100%
# horse: 100%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:27642): Gtk-WARNING **: 07:11:35.561: cannot open display:

# %%
#Let's define some functions that will let us show images, and upload and 
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
imShow('predictions.jpg')

# %%
cd /content/darknet/
# Out:
# /content/darknet

# %%
from google.colab import files
uploaded = files.upload() 
for name, data in uploaded.items():
  with open(name, 'wb') as f:
    f.write(data)
    print ('saved file', name)
# Out:
#      <input type="file" id="files-33e565aa-9bc2-4d0f-a462-e3731cfcbbd9" name="files[]" multiple disabled />
#      <output id="result-33e565aa-9bc2-4d0f-a462-e3731cfcbbd9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving obj (5).data to obj (5).data
# saved file obj (5).data

# %%
# %chmod +rwx backup/
# Out:
# UsageError: Line magic function `%chmod` not found.

# %%
# cd backup/
# mkdir backup

# %%
# !./darknet detector train data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg data_for_colab/yolov3-tiny.conv.15 -dont_show
# !./darknet detector train data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_1000.weights -dont_show
# Out:
#  CUDA-version: 8000 (10010)
#  Warning: CUDA-version is lower than Driver-version!
# , GPU count: 1
#  OpenCV version: 3.2.0
# yolov3-tiny-obj
# net.optimized_memory = 0
# batch = 32, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#    9 max                2x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   10 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   11 max                2x 2/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.000 BF
#   12 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   13 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   14 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   15 conv     18       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  18 0.003 BF
#   16 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   17 route  13 		                           ->   13 x  13 x 256
#   18 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   19 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   20 route  19 8 	                           ->   26 x  26 x 384
#   21 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   22 conv     18       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  18 0.006 BF
#   23 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 5.448
#  Allocate additional workspace_size = 24.92 MB
# Loading weights from backup/yolov3-tiny-obj_1000.weights...
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# Done! Loaded 24 layers from weights-file
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
# Resizing, random_coef = 1.40
# 608 x 608
#  try to allocate additional workspace_size = 53.23 MB
#  CUDA allocate done!
# Loaded: 0.000054 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.700819, GIOU: 0.695407), Class: 0.996242, Obj: 0.550295, No Obj: 0.001385, .5R: 0.909091, .75R: 0.484848, count: 33, loss = 0.869463, class_loss = 0.500137, iou_loss = 0.369325
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000015, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.684752, GIOU: 0.679341), Class: 0.997744, Obj: 0.580802, No Obj: 0.001445, .5R: 0.852941, .75R: 0.411765, count: 34, loss = 0.891430, class_loss = 0.503297, iou_loss = 0.388133
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000015, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
#
#  1001: 0.440224, 0.440224 avg loss, 0.001000 rate, 3.962335 seconds, 64064 images
# Loaded: 0.000057 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.735102, GIOU: 0.725997), Class: 0.998659, Obj: 0.660124, No Obj: 0.001313, .5R: 0.937500, .75R: 0.500000, count: 32, loss = 0.617690, class_loss = 0.366812, iou_loss = 0.250878
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000015, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.712556, GIOU: 0.705749), Class: 0.998132, Obj: 0.677513, No Obj: 0.001394, .5R: 0.914286, .75R: 0.400000, count: 35, loss = 0.768649, class_loss = 0.415139, iou_loss = 0.353511
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000015, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
#
#  1002: 0.346586, 0.430860 avg loss, 0.001000 rate, 4.479715 seconds, 64128 images
# Loaded: 0.000057 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.714891, GIOU: 0.707738), Class: 0.997033, Obj: 0.538149, No Obj: 0.001099, .5R: 0.906250, .75R: 0.562500, count: 32, loss = 0.722245, class_loss = 0.409181, iou_loss = 0.313064
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.660502, GIOU: 0.654376), Class: 0.996770, Obj: 0.486110, No Obj: 0.001109, .5R: 0.800000, .75R: 0.400000, count: 35, loss = 0.979550, class_loss = 0.566558, iou_loss = 0.412992
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000015, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
#
#  1003: 0.425449, 0.430319 avg loss, 0.001000 rate, 4.680212 seconds, 64192 images
# Loaded: 0.000054 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.665051, GIOU: 0.655099), Class: 0.997961, Obj: 0.519867, No Obj: 0.000986, .5R: 0.823529, .75R: 0.382353, count: 34, loss = 0.890745, class_loss = 0.470310, iou_loss = 0.420435
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.683715, GIOU: 0.674014), Class: 0.993409, Obj: 0.510939, No Obj: 0.001014, .5R: 0.875000, .75R: 0.437500, count: 32, loss = 0.875413, class_loss = 0.485357, iou_loss = 0.390056
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000015, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
#
#  1004: 0.441541, 0.431441 avg loss, 0.001000 rate, 4.706589 seconds, 64256 images
# Loaded: 0.000061 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.717109, GIOU: 0.712095), Class: 0.997751, Obj: 0.604587, No Obj: 0.001166, .5R: 1.000000, .75R: 0.375000, count: 32, loss = 0.666326, class_loss = 0.406807, iou_loss = 0.259519
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000015, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.657494, GIOU: 0.644635), Class: 0.997162, Obj: 0.522787, No Obj: 0.001073, .5R: 0.848485, .75R: 0.333333, count: 33, loss = 0.887796, class_loss = 0.465485, iou_loss = 0.422311
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
#
#  1005: 0.388531, 0.427150 avg loss, 0.001000 rate, 4.692604 seconds, 64320 images
# Loaded: 0.000075 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.682638, GIOU: 0.651210), Class: 0.981875, Obj: 0.520147, No Obj: 0.001138, .5R: 0.882353, .75R: 0.470588, count: 34, loss = 0.894041, class_loss = 0.495536, iou_loss = 0.398505
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.661958, GIOU: 0.638196), Class: 0.997456, Obj: 0.607033, No Obj: 0.001007, .5R: 0.900000, .75R: 0.233333, count: 30, loss = 1.033867, class_loss = 0.335363, iou_loss = 0.698503
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
#
#  1006: 0.481978, 0.432633 avg loss, 0.001000 rate, 4.695685 seconds, 64384 images
# Loaded: 0.000053 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.730035, GIOU: 0.725455), Class: 0.998710, Obj: 0.677852, No Obj: 0.001115, .5R: 0.968750, .75R: 0.437500, count: 32, loss = 0.518129, class_loss = 0.279716, iou_loss = 0.238413
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.700338, GIOU: 0.694231), Class: 0.997259, Obj: 0.573884, No Obj: 0.001223, .5R: 0.942857, .75R: 0.342857, count: 35, loss = 0.726817, class_loss = 0.410867, iou_loss = 0.315950
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
#
#  1007: 0.311237, 0.420494 avg loss, 0.001000 rate, 4.698088 seconds, 64448 images
# Loaded: 0.000069 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.672442, GIOU: 0.647371), Class: 0.989482, Obj: 0.544696, No Obj: 0.001130, .5R: 0.906250, .75R: 0.343750, count: 32, loss = 0.879829, class_loss = 0.436655, iou_loss = 0.443174
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.686001, GIOU: 0.680217), Class: 0.997610, Obj: 0.485352, No Obj: 0.001040, .5R: 0.870968, .75R: 0.354839, count: 31, loss = 0.870056, class_loss = 0.519733, iou_loss = 0.350323
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
#
#  1008: 0.437472, 0.422191 avg loss, 0.001000 rate, 4.694624 seconds, 64512 images
# Loaded: 0.000062 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.722810, GIOU: 0.716551), Class: 0.998006, Obj: 0.585452, No Obj: 0.001102, .5R: 0.909091, .75R: 0.484848, count: 33, loss = 0.604566, class_loss = 0.349052, iou_loss = 0.255514
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.723817, GIOU: 0.718245), Class: 0.998110, Obj: 0.555957, No Obj: 0.001073, .5R: 1.000000, .75R: 0.468750, count: 32, loss = 0.764947, class_loss = 0.469410, iou_loss = 0.295536
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
#
#  1009: 0.342379, 0.414210 avg loss, 0.001000 rate, 4.704825 seconds, 64576 images
# Loaded: 0.000072 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.654933, GIOU: 0.647036), Class: 0.997016, Obj: 0.567979, No Obj: 0.001085, .5R: 0.838710, .75R: 0.290323, count: 31, loss = 0.831430, class_loss = 0.445107, iou_loss = 0.386323
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000002, class_loss = 0.000002, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.616499, GIOU: 0.609104), Class: 0.998068, Obj: 0.555722, No Obj: 0.001186, .5R: 0.764706, .75R: 0.294118, count: 34, loss = 1.158733, class_loss = 0.501495, iou_loss = 0.657239
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1010: 0.497541, 0.422543 avg loss, 0.001000 rate, 4.710439 seconds, 64640 images
# Resizing, random_coef = 1.40
# 416 x 416
#  try to allocate additional workspace_size = 24.92 MB
#  CUDA allocate done!
# Loaded: 0.000064 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.647011, GIOU: 0.627518), Class: 0.994446, Obj: 0.566110, No Obj: 0.002131, .5R: 0.812500, .75R: 0.218750, count: 32, loss = 0.781304, class_loss = 0.433565, iou_loss = 0.347739
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.717246, GIOU: 0.707017), Class: 0.998327, Obj: 0.685813, No Obj: 0.002113, .5R: 0.967742, .75R: 0.419355, count: 31, loss = 0.480347, class_loss = 0.230596, iou_loss = 0.249750
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1011: 0.315413, 0.411830 avg loss, 0.001000 rate, 1.798913 seconds, 64704 images
# Loaded: 0.000057 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.718318, GIOU: 0.707930), Class: 0.998563, Obj: 0.707911, No Obj: 0.002150, .5R: 0.906250, .75R: 0.437500, count: 32, loss = 0.459212, class_loss = 0.202045, iou_loss = 0.257167
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.704421, GIOU: 0.691991), Class: 0.998560, Obj: 0.759136, No Obj: 0.002369, .5R: 0.939394, .75R: 0.424242, count: 33, loss = 0.510400, class_loss = 0.262097, iou_loss = 0.248303
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1012: 0.242403, 0.394888 avg loss, 0.001000 rate, 2.264864 seconds, 64768 images
# Loaded: 0.000068 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.700846, GIOU: 0.685436), Class: 0.995137, Obj: 0.757938, No Obj: 0.002170, .5R: 0.870968, .75R: 0.354839, count: 31, loss = 0.488553, class_loss = 0.193398, iou_loss = 0.295155
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000014, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.727112, GIOU: 0.718264), Class: 0.997821, Obj: 0.644112, No Obj: 0.002454, .5R: 0.969697, .75R: 0.424242, count: 33, loss = 0.554435, class_loss = 0.338679, iou_loss = 0.215756
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1013: 0.260747, 0.381474 avg loss, 0.001000 rate, 2.261349 seconds, 64832 images
# Loaded: 0.000063 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.668888, GIOU: 0.645641), Class: 0.997715, Obj: 0.649770, No Obj: 0.002433, .5R: 0.848485, .75R: 0.333333, count: 33, loss = 0.718290, class_loss = 0.403728, iou_loss = 0.314562
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.712227, GIOU: 0.707011), Class: 0.997322, Obj: 0.597034, No Obj: 0.002365, .5R: 0.937500, .75R: 0.468750, count: 32, loss = 0.698850, class_loss = 0.402795, iou_loss = 0.296055
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1014: 0.354285, 0.378755 avg loss, 0.001000 rate, 2.261934 seconds, 64896 images
# Loaded: 0.000086 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.701720, GIOU: 0.689830), Class: 0.998570, Obj: 0.692680, No Obj: 0.002814, .5R: 0.942857, .75R: 0.285714, count: 35, loss = 0.611488, class_loss = 0.340948, iou_loss = 0.270540
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.722176, GIOU: 0.715281), Class: 0.999184, Obj: 0.793852, No Obj: 0.002576, .5R: 0.968750, .75R: 0.437500, count: 32, loss = 0.495929, class_loss = 0.274997, iou_loss = 0.220932
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1015: 0.276855, 0.368565 avg loss, 0.001000 rate, 2.269678 seconds, 64960 images
# Loaded: 0.000066 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.678076, GIOU: 0.667119), Class: 0.998584, Obj: 0.739502, No Obj: 0.002316, .5R: 0.906250, .75R: 0.312500, count: 32, loss = 0.508422, class_loss = 0.207103, iou_loss = 0.301319
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.712705, GIOU: 0.709273), Class: 0.998174, Obj: 0.774567, No Obj: 0.002832, .5R: 0.909091, .75R: 0.484848, count: 33, loss = 0.554883, class_loss = 0.280127, iou_loss = 0.274756
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1016: 0.265827, 0.358291 avg loss, 0.001000 rate, 2.267575 seconds, 65024 images
# Loaded: 0.000055 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.715287, GIOU: 0.708747), Class: 0.998198, Obj: 0.705932, No Obj: 0.002333, .5R: 0.906250, .75R: 0.500000, count: 32, loss = 0.530389, class_loss = 0.286321, iou_loss = 0.244068
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.696087, GIOU: 0.687941), Class: 0.998380, Obj: 0.705624, No Obj: 0.002583, .5R: 0.969697, .75R: 0.393939, count: 33, loss = 0.551429, class_loss = 0.294242, iou_loss = 0.257187
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1017: 0.270455, 0.349507 avg loss, 0.001000 rate, 2.272595 seconds, 65088 images
# Loaded: 0.000061 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.668624, GIOU: 0.652403), Class: 0.998178, Obj: 0.673843, No Obj: 0.002363, .5R: 0.812500, .75R: 0.406250, count: 32, loss = 0.631805, class_loss = 0.287532, iou_loss = 0.344273
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.642070, GIOU: 0.633310), Class: 0.996791, Obj: 0.562695, No Obj: 0.002058, .5R: 0.878788, .75R: 0.272727, count: 33, loss = 0.789813, class_loss = 0.445411, iou_loss = 0.344402
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1018: 0.355405, 0.350097 avg loss, 0.001000 rate, 2.276600 seconds, 65152 images
# Loaded: 0.000059 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.677272, GIOU: 0.667029), Class: 0.997596, Obj: 0.598034, No Obj: 0.002133, .5R: 0.909091, .75R: 0.333333, count: 33, loss = 0.639258, class_loss = 0.379947, iou_loss = 0.259310
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.692795, GIOU: 0.683231), Class: 0.998439, Obj: 0.705432, No Obj: 0.002365, .5R: 0.866667, .75R: 0.400000, count: 30, loss = 0.539953, class_loss = 0.267911, iou_loss = 0.272042
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1019: 0.294803, 0.344568 avg loss, 0.001000 rate, 2.274503 seconds, 65216 images
# Loaded: 0.000094 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.724302, GIOU: 0.717109), Class: 0.996571, Obj: 0.505700, No Obj: 0.002055, .5R: 0.891892, .75R: 0.567568, count: 37, loss = 0.817616, class_loss = 0.519674, iou_loss = 0.297941
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.726037, GIOU: 0.718874), Class: 0.998567, Obj: 0.729243, No Obj: 0.002123, .5R: 0.900000, .75R: 0.533333, count: 30, loss = 0.457120, class_loss = 0.238130, iou_loss = 0.218990
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1020: 0.318684, 0.341979 avg loss, 0.001000 rate, 2.279329 seconds, 65280 images
# Resizing, random_coef = 1.40
# 384 x 384
#  try to allocate additional workspace_size = 21.23 MB
#  CUDA allocate done!
# Loaded: 0.000053 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.671795, GIOU: 0.655749), Class: 0.998113, Obj: 0.671720, No Obj: 0.002535, .5R: 0.848485, .75R: 0.484848, count: 33, loss = 0.579030, class_loss = 0.275682, iou_loss = 0.303348
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.672214, GIOU: 0.662432), Class: 0.998055, Obj: 0.709903, No Obj: 0.002523, .5R: 0.939394, .75R: 0.242424, count: 33, loss = 0.675700, class_loss = 0.323773, iou_loss = 0.351927
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1021: 0.313683, 0.339150 avg loss, 0.001000 rate, 1.278376 seconds, 65344 images
# Loaded: 0.000056 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.707295, GIOU: 0.699763), Class: 0.997294, Obj: 0.608303, No Obj: 0.002374, .5R: 0.941176, .75R: 0.470588, count: 34, loss = 0.633803, class_loss = 0.374465, iou_loss = 0.259338
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.644720, GIOU: 0.634672), Class: 0.998606, Obj: 0.636597, No Obj: 0.002571, .5R: 0.818182, .75R: 0.242424, count: 33, loss = 1.000807, class_loss = 0.302106, iou_loss = 0.698702
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1022: 0.408653, 0.346100 avg loss, 0.001000 rate, 1.973678 seconds, 65408 images
# Loaded: 0.000053 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.673626, GIOU: 0.662529), Class: 0.997867, Obj: 0.623086, No Obj: 0.002340, .5R: 0.937500, .75R: 0.312500, count: 32, loss = 0.563532, class_loss = 0.308782, iou_loss = 0.254750
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.641877, GIOU: 0.629657), Class: 0.997787, Obj: 0.723447, No Obj: 0.002152, .5R: 0.793103, .75R: 0.310345, count: 29, loss = 0.579935, class_loss = 0.205342, iou_loss = 0.374593
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1023: 0.285867, 0.340077 avg loss, 0.001000 rate, 1.967159 seconds, 65472 images
# Loaded: 0.000088 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.652217, GIOU: 0.642357), Class: 0.998254, Obj: 0.612774, No Obj: 0.002663, .5R: 0.909091, .75R: 0.212121, count: 33, loss = 0.758965, class_loss = 0.457753, iou_loss = 0.301212
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.719944, GIOU: 0.708197), Class: 0.998662, Obj: 0.733670, No Obj: 0.002950, .5R: 0.939394, .75R: 0.454545, count: 33, loss = 0.505390, class_loss = 0.277487, iou_loss = 0.227902
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1024: 0.316089, 0.337678 avg loss, 0.001000 rate, 1.979130 seconds, 65536 images
# Loaded: 0.000063 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.726182, GIOU: 0.720008), Class: 0.998417, Obj: 0.747777, No Obj: 0.003000, .5R: 0.968750, .75R: 0.375000, count: 32, loss = 0.526060, class_loss = 0.296817, iou_loss = 0.229242
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.720613, GIOU: 0.709924), Class: 0.998646, Obj: 0.803056, No Obj: 0.003137, .5R: 0.968750, .75R: 0.406250, count: 32, loss = 0.449145, class_loss = 0.238499, iou_loss = 0.210647
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1025: 0.243802, 0.328290 avg loss, 0.001000 rate, 1.970376 seconds, 65600 images
# Loaded: 0.000067 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.683066, GIOU: 0.655160), Class: 0.981640, Obj: 0.640509, No Obj: 0.002530, .5R: 0.906250, .75R: 0.312500, count: 32, loss = 0.659886, class_loss = 0.300792, iou_loss = 0.359094
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.663051, GIOU: 0.642646), Class: 0.998129, Obj: 0.821983, No Obj: 0.002713, .5R: 0.903226, .75R: 0.387097, count: 31, loss = 0.670554, class_loss = 0.163806, iou_loss = 0.506748
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1026: 0.332610, 0.328722 avg loss, 0.001000 rate, 1.968086 seconds, 65664 images
# Loaded: 0.000059 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.691237, GIOU: 0.683356), Class: 0.997417, Obj: 0.662045, No Obj: 0.002678, .5R: 0.878788, .75R: 0.424242, count: 33, loss = 0.592063, class_loss = 0.301699, iou_loss = 0.290364
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.747809, GIOU: 0.739329), Class: 0.997701, Obj: 0.754445, No Obj: 0.003031, .5R: 1.000000, .75R: 0.515152, count: 33, loss = 0.404910, class_loss = 0.211564, iou_loss = 0.193346
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1027: 0.249243, 0.320774 avg loss, 0.001000 rate, 1.971634 seconds, 65728 images
# Loaded: 0.000060 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.676826, GIOU: 0.665305), Class: 0.998159, Obj: 0.743331, No Obj: 0.002913, .5R: 0.878788, .75R: 0.333333, count: 33, loss = 0.574170, class_loss = 0.289048, iou_loss = 0.285121
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.696758, GIOU: 0.682762), Class: 0.998696, Obj: 0.696841, No Obj: 0.003192, .5R: 0.882353, .75R: 0.352941, count: 34, loss = 0.611237, class_loss = 0.314524, iou_loss = 0.296713
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1028: 0.296352, 0.318332 avg loss, 0.001000 rate, 1.974217 seconds, 65792 images
# Loaded: 0.000056 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.696641, GIOU: 0.682532), Class: 0.998152, Obj: 0.706869, No Obj: 0.003150, .5R: 0.972222, .75R: 0.361111, count: 36, loss = 0.607303, class_loss = 0.287382, iou_loss = 0.319922
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.670026, GIOU: 0.659866), Class: 0.998789, Obj: 0.692707, No Obj: 0.002922, .5R: 0.875000, .75R: 0.281250, count: 32, loss = 0.682955, class_loss = 0.359100, iou_loss = 0.323855
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1029: 0.322565, 0.318755 avg loss, 0.001000 rate, 1.992212 seconds, 65856 images
# Loaded: 0.000044 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.705908, GIOU: 0.697295), Class: 0.995804, Obj: 0.707955, No Obj: 0.002834, .5R: 0.909091, .75R: 0.333333, count: 33, loss = 0.575198, class_loss = 0.324345, iou_loss = 0.250852
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.692779, GIOU: 0.684903), Class: 0.998341, Obj: 0.740388, No Obj: 0.002951, .5R: 0.939394, .75R: 0.363636, count: 33, loss = 0.586777, class_loss = 0.302375, iou_loss = 0.284402
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1030: 0.290494, 0.315929 avg loss, 0.001000 rate, 1.968319 seconds, 65920 images
# Resizing, random_coef = 1.40
# 384 x 384
#  try to allocate additional workspace_size = 21.23 MB
#  CUDA allocate done!
# Loaded: 0.000055 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.716677, GIOU: 0.702705), Class: 0.998012, Obj: 0.629870, No Obj: 0.002589, .5R: 0.909091, .75R: 0.454545, count: 33, loss = 0.654913, class_loss = 0.377181, iou_loss = 0.277732
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.703681, GIOU: 0.692229), Class: 0.998376, Obj: 0.702475, No Obj: 0.002631, .5R: 0.878788, .75R: 0.454545, count: 33, loss = 0.551363, class_loss = 0.257927, iou_loss = 0.293436
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1031: 0.301569, 0.314493 avg loss, 0.001000 rate, 1.277445 seconds, 65984 images
# Loaded: 0.000056 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.703721, GIOU: 0.696160), Class: 0.998409, Obj: 0.719924, No Obj: 0.002589, .5R: 0.937500, .75R: 0.375000, count: 32, loss = 0.511843, class_loss = 0.297341, iou_loss = 0.214502
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.676308, GIOU: 0.659979), Class: 0.995675, Obj: 0.633870, No Obj: 0.002644, .5R: 0.848485, .75R: 0.333333, count: 33, loss = 0.653159, class_loss = 0.330071, iou_loss = 0.323088
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1032: 0.291251, 0.312169 avg loss, 0.001000 rate, 1.987671 seconds, 66048 images
# Loaded: 0.000057 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.686774, GIOU: 0.673276), Class: 0.998180, Obj: 0.701468, No Obj: 0.002660, .5R: 0.909091, .75R: 0.333333, count: 33, loss = 0.547576, class_loss = 0.258780, iou_loss = 0.288796
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.711602, GIOU: 0.702474), Class: 0.999221, Obj: 0.770145, No Obj: 0.002673, .5R: 0.909091, .75R: 0.484848, count: 33, loss = 0.409336, class_loss = 0.211692, iou_loss = 0.197644
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1033: 0.239228, 0.304875 avg loss, 0.001000 rate, 1.984338 seconds, 66112 images
# Loaded: 0.000061 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.685206, GIOU: 0.677727), Class: 0.998546, Obj: 0.602058, No Obj: 0.002715, .5R: 0.942857, .75R: 0.314286, count: 35, loss = 0.720364, class_loss = 0.402958, iou_loss = 0.317407
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.712876, GIOU: 0.698989), Class: 0.998376, Obj: 0.708163, No Obj: 0.002408, .5R: 1.000000, .75R: 0.387097, count: 31, loss = 0.446638, class_loss = 0.228402, iou_loss = 0.218236
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1034: 0.291751, 0.303563 avg loss, 0.001000 rate, 1.993688 seconds, 66176 images
# Loaded: 0.000056 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.688515, GIOU: 0.679140), Class: 0.998236, Obj: 0.677847, No Obj: 0.002641, .5R: 0.906250, .75R: 0.406250, count: 32, loss = 0.593432, class_loss = 0.307169, iou_loss = 0.286263
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.695689, GIOU: 0.684218), Class: 0.998754, Obj: 0.721698, No Obj: 0.002701, .5R: 0.935484, .75R: 0.322581, count: 31, loss = 0.482622, class_loss = 0.239880, iou_loss = 0.242741
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1035: 0.269014, 0.300108 avg loss, 0.001000 rate, 1.995646 seconds, 66240 images
# Loaded: 0.000053 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.662344, GIOU: 0.652691), Class: 0.996023, Obj: 0.637367, No Obj: 0.002537, .5R: 0.812500, .75R: 0.343750, count: 32, loss = 0.649499, class_loss = 0.337689, iou_loss = 0.311810
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.734130, GIOU: 0.726451), Class: 0.999183, Obj: 0.803315, No Obj: 0.002541, .5R: 1.000000, .75R: 0.419355, count: 31, loss = 0.330083, class_loss = 0.159570, iou_loss = 0.170513
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  1036: 0.244896, 0.294586 avg loss, 0.001000 rate, 1.998550 seconds, 66304 images
# Loaded: 0.000085 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.686787, GIOU: 0.677183), Class: 0.998521, Obj: 0.686672, No Obj: 0.002718, .5R: 0.970588, .75R: 0.294118, count: 34, loss = 0.589403, class_loss = 0.301772, iou_loss = 0.287632
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.709231, GIOU: 0.701699), Class: 0.996113, Obj: 0.649290, No Obj: 0.002659, .5R: 0.911765, .75R: 0.382353, count: 34, loss = 0.552034, class_loss = 0.315597, iou_loss = 0.236437
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  1037: 0.285360, 0.293664 avg loss, 0.001000 rate, 1.998216 seconds, 66368 images
# Loaded: 0.000073 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.716508, GIOU: 0.706187), Class: 0.998369, Obj: 0.831975, No Obj: 0.002743, .5R: 0.939394, .75R: 0.484848, count: 33, loss = 0.416014, class_loss = 0.128271, iou_loss = 0.287743
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.668619, GIOU: 0.654244), Class: 0.997451, Obj: 0.704284, No Obj: 0.002641, .5R: 0.939394, .75R: 0.303030, count: 33, loss = 0.590678, class_loss = 0.287407, iou_loss = 0.303270
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1038: 0.251673, 0.289465 avg loss, 0.001000 rate, 2.002179 seconds, 66432 images
# Loaded: 0.000062 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.661590, GIOU: 0.644473), Class: 0.997297, Obj: 0.662405, No Obj: 0.002614, .5R: 0.843750, .75R: 0.312500, count: 32, loss = 0.641401, class_loss = 0.304651, iou_loss = 0.336750
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.693034, GIOU: 0.673456), Class: 0.997847, Obj: 0.701636, No Obj: 0.002662, .5R: 0.906250, .75R: 0.468750, count: 32, loss = 0.594384, class_loss = 0.285971, iou_loss = 0.308413
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  1039: 0.308947, 0.291413 avg loss, 0.001000 rate, 1.997760 seconds, 66496 images
# Loaded: 0.000060 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.688071, GIOU: 0.678003), Class: 0.998720, Obj: 0.731749, No Obj: 0.002680, .5R: 0.909091, .75R: 0.272727, count: 33, loss = 0.488611, class_loss = 0.224796, iou_loss = 0.263815
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.698650, GIOU: 0.685377), Class: 0.997551, Obj: 0.614841, No Obj: 0.002782, .5R: 0.939394, .75R: 0.484848, count: 33, loss = 0.678947, class_loss = 0.368825, iou_loss = 0.310122
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000013, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
#
#  1040: 0.291890, 0.291461 avg loss, 0.001000 rate, 2.008776 seconds, 66560 images
# Resizing, random_coef = 1.40
# 384 x 384
#  try to allocate additional workspace_size = 21.23 MB
#  CUDA allocate done!
# Loaded: 0.000051 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.717679, GIOU: 0.701425), Class: 0.998591, Obj: 0.745921, No Obj: 0.003006, .5R: 0.941176, .75R: 0.470588, count: 34, loss = 0.634431, class_loss = 0.308235, iou_loss = 0.326196
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000001, class_loss = 0.000001, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.676588, GIOU: 0.666393), Class: 0.998706, Obj: 0.784025, No Obj: 0.002989, .5R: 0.939394, .75R: 0.181818, count: 33, loss = 0.544216, class_loss = 0.280652, iou_loss = 0.263564
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  1041: 0.294662, 0.291781 avg loss, 0.001000 rate, 1.408529 seconds, 66624 images
# Loaded: 0.000057 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.681522, GIOU: 0.671246), Class: 0.996008, Obj: 0.767765, No Obj: 0.003188, .5R: 0.882353, .75R: 0.323529, count: 34, loss = 0.578042, class_loss = 0.283342, iou_loss = 0.294700
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000012, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# ...
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  1997: 0.124489, 0.182572 avg loss, 0.001000 rate, 2.316569 seconds, 127808 images
# Loaded: 0.000090 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.816999, GIOU: 0.814522), Class: 0.999058, Obj: 0.774962, No Obj: 0.002839, .5R: 1.000000, .75R: 0.857143, count: 35, loss = 0.308064, class_loss = 0.183338, iou_loss = 0.124727
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.771179, GIOU: 0.766682), Class: 0.998994, Obj: 0.810333, No Obj: 0.002816, .5R: 0.939394, .75R: 0.696970, count: 33, loss = 0.352249, class_loss = 0.206803, iou_loss = 0.145446
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  1998: 0.165078, 0.180822 avg loss, 0.001000 rate, 2.300891 seconds, 127872 images
# Loaded: 0.000054 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.755194, GIOU: 0.752659), Class: 0.998707, Obj: 0.824474, No Obj: 0.002412, .5R: 0.968750, .75R: 0.562500, count: 32, loss = 0.334176, class_loss = 0.188689, iou_loss = 0.145487
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.737204, GIOU: 0.735537), Class: 0.999633, Obj: 0.929449, No Obj: 0.002648, .5R: 0.969697, .75R: 0.484848, count: 33, loss = 0.314276, class_loss = 0.148475, iou_loss = 0.165801
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000003, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  1999: 0.162113, 0.178951 avg loss, 0.001000 rate, 2.308729 seconds, 127936 images
# Loaded: 0.000056 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.743016, GIOU: 0.740179), Class: 0.995664, Obj: 0.842146, No Obj: 0.002815, .5R: 0.970588, .75R: 0.529412, count: 34, loss = 0.575554, class_loss = 0.208876, iou_loss = 0.366678
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.715780, GIOU: 0.708778), Class: 0.999292, Obj: 0.822335, No Obj: 0.002844, .5R: 0.942857, .75R: 0.457143, count: 35, loss = 0.430961, class_loss = 0.203611, iou_loss = 0.227350
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2000: 0.251629, 0.186219 avg loss, 0.001000 rate, 2.308108 seconds, 128000 images
# Saving weights to backup//yolov3-tiny-obj_2000.weights
# Saving weights to backup//yolov3-tiny-obj_last.weights
# Resizing, random_coef = 1.40
# 384 x 384
#  try to allocate additional workspace_size = 21.23 MB
#  CUDA allocate done!
# Loaded: 0.152164 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.750512, GIOU: 0.745429), Class: 0.999394, Obj: 0.837024, No Obj: 0.002835, .5R: 0.966667, .75R: 0.600000, count: 30, loss = 0.277207, class_loss = 0.137024, iou_loss = 0.140183
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.772641, GIOU: 0.765936), Class: 0.998815, Obj: 0.805112, No Obj: 0.003176, .5R: 0.969697, .75R: 0.696970, count: 33, loss = 0.448865, class_loss = 0.271179, iou_loss = 0.177685
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2001: 0.181518, 0.185749 avg loss, 0.001000 rate, 1.387475 seconds, 128064 images
# Loaded: 0.000047 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.728316, GIOU: 0.724968), Class: 0.999135, Obj: 0.822372, No Obj: 0.003251, .5R: 0.939394, .75R: 0.454545, count: 33, loss = 0.493221, class_loss = 0.214643, iou_loss = 0.278579
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000003, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.766514, GIOU: 0.761971), Class: 0.999358, Obj: 0.785596, No Obj: 0.003309, .5R: 0.969697, .75R: 0.606061, count: 33, loss = 0.380985, class_loss = 0.242964, iou_loss = 0.138021
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000003, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2002: 0.218552, 0.189029 avg loss, 0.001000 rate, 2.014336 seconds, 128128 images
# Loaded: 0.000049 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.736511, GIOU: 0.730102), Class: 0.999336, Obj: 0.836812, No Obj: 0.002946, .5R: 0.937500, .75R: 0.562500, count: 32, loss = 0.315162, class_loss = 0.130463, iou_loss = 0.184698
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.720537, GIOU: 0.717995), Class: 0.998913, Obj: 0.824558, No Obj: 0.003025, .5R: 0.969697, .75R: 0.424242, count: 33, loss = 0.410700, class_loss = 0.191725, iou_loss = 0.218975
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2003: 0.181465, 0.188273 avg loss, 0.001000 rate, 1.988652 seconds, 128192 images
# Loaded: 0.000053 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.713550, GIOU: 0.705547), Class: 0.999532, Obj: 0.868566, No Obj: 0.002714, .5R: 0.939394, .75R: 0.545455, count: 33, loss = 0.389685, class_loss = 0.111747, iou_loss = 0.277939
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.743050, GIOU: 0.739663), Class: 0.998903, Obj: 0.875740, No Obj: 0.003072, .5R: 1.000000, .75R: 0.468750, count: 32, loss = 0.306351, class_loss = 0.132892, iou_loss = 0.173459
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2004: 0.174009, 0.186846 avg loss, 0.001000 rate, 1.999384 seconds, 128256 images
# Loaded: 0.000057 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.798304, GIOU: 0.794515), Class: 0.999076, Obj: 0.749819, No Obj: 0.002878, .5R: 1.000000, .75R: 0.735294, count: 34, loss = 0.316474, class_loss = 0.200765, iou_loss = 0.115709
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.770380, GIOU: 0.761799), Class: 0.998985, Obj: 0.768465, No Obj: 0.002773, .5R: 0.968750, .75R: 0.656250, count: 32, loss = 0.381865, class_loss = 0.225778, iou_loss = 0.156088
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2005: 0.174585, 0.185620 avg loss, 0.001000 rate, 1.994715 seconds, 128320 images
# Loaded: 0.000062 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.760897, GIOU: 0.756998), Class: 0.999328, Obj: 0.778977, No Obj: 0.002989, .5R: 0.937500, .75R: 0.593750, count: 32, loss = 0.379614, class_loss = 0.207305, iou_loss = 0.172309
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.687963, GIOU: 0.678308), Class: 0.999288, Obj: 0.841276, No Obj: 0.002650, .5R: 0.933333, .75R: 0.433333, count: 30, loss = 0.438757, class_loss = 0.172905, iou_loss = 0.265852
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2006: 0.204593, 0.187518 avg loss, 0.001000 rate, 2.001004 seconds, 128384 images
# Loaded: 0.000061 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.787399, GIOU: 0.780317), Class: 0.999287, Obj: 0.841648, No Obj: 0.003067, .5R: 0.967742, .75R: 0.774194, count: 31, loss = 0.250424, class_loss = 0.123990, iou_loss = 0.126433
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000003, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.799720, GIOU: 0.796458), Class: 0.999319, Obj: 0.849790, No Obj: 0.003044, .5R: 1.000000, .75R: 0.852941, count: 34, loss = 0.228490, class_loss = 0.094972, iou_loss = 0.133518
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2007: 0.119728, 0.180739 avg loss, 0.001000 rate, 1.999099 seconds, 128448 images
# Loaded: 0.000066 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.764614, GIOU: 0.759217), Class: 0.999445, Obj: 0.888445, No Obj: 0.003140, .5R: 1.000000, .75R: 0.656250, count: 32, loss = 0.283616, class_loss = 0.156409, iou_loss = 0.127206
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.726545, GIOU: 0.719609), Class: 0.998812, Obj: 0.834981, No Obj: 0.003343, .5R: 0.914286, .75R: 0.514286, count: 35, loss = 0.405851, class_loss = 0.203558, iou_loss = 0.202293
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2008: 0.172367, 0.179901 avg loss, 0.001000 rate, 2.004125 seconds, 128512 images
# Loaded: 0.000059 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.754381, GIOU: 0.740349), Class: 0.999071, Obj: 0.800322, No Obj: 0.002839, .5R: 0.914286, .75R: 0.600000, count: 35, loss = 0.354878, class_loss = 0.183856, iou_loss = 0.171022
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.761717, GIOU: 0.751802), Class: 0.999207, Obj: 0.891989, No Obj: 0.002686, .5R: 0.970588, .75R: 0.676471, count: 34, loss = 0.511967, class_loss = 0.071852, iou_loss = 0.440115
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2009: 0.216711, 0.183582 avg loss, 0.001000 rate, 1.997492 seconds, 128576 images
# Loaded: 0.000053 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.764773, GIOU: 0.760788), Class: 0.999362, Obj: 0.878818, No Obj: 0.003096, .5R: 0.968750, .75R: 0.625000, count: 32, loss = 0.250995, class_loss = 0.116872, iou_loss = 0.134123
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.743519, GIOU: 0.735317), Class: 0.999398, Obj: 0.842314, No Obj: 0.002958, .5R: 0.941176, .75R: 0.500000, count: 34, loss = 0.344593, class_loss = 0.163294, iou_loss = 0.181298
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2010: 0.148897, 0.180114 avg loss, 0.001000 rate, 1.998322 seconds, 128640 images
# Resizing, random_coef = 1.40
# 416 x 416
#  try to allocate additional workspace_size = 24.92 MB
#  CUDA allocate done!
# Loaded: 0.000053 seconds
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.741505, GIOU: 0.738703), Class: 0.999373, Obj: 0.869457, No Obj: 0.003050, .5R: 1.000000, .75R: 0.485714, count: 35, loss = 0.376002, class_loss = 0.201370, iou_loss = 0.174632
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 16 Avg (IOU: 0.728899, GIOU: 0.721043), Class: 0.999516, Obj: 0.910017, No Obj: 0.002455, .5R: 1.000000, .75R: 0.500000, count: 30, loss = 0.285099, class_loss = 0.101030, iou_loss = 0.184069
# v3 (mse loss, Normalizer: (iou: 0.750000, cls: 1.000000) Region 23 Avg (IOU: -nan, GIOU: -nan), Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan, count: 0, loss = 0.000000, class_loss = 0.000000, iou_loss = 0.000000
#
#  2011: 0.165275, 0.178630 avg loss, 0.001000 rate, 1.475877 seconds, 128704 images
# Loaded: 0.000062 seconds
# ^C

# %%
pwd
# Out:
# '/content/darknet/data_for_colab'

# %%
# %cd ..
# Out:
# /content/darknet

# %%
ls

# %%
from google.colab import files
uploaded = files.upload() 
for name, data in uploaded.items():
  with open(name, 'wb') as f:
    f.write(data)
    print ('saved file', name)
# Out:
#      <input type="file" id="files-93e405df-180e-4ee5-98e1-226de338c6f2" name="files[]" multiple disabled />
#      <output id="result-93e405df-180e-4ee5-98e1-226de338c6f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dark.png to dark.png
# saved file dark.png

# %%
#%cd /content/darknet/backup/
 #ls
# Out:
# /content/darknet

# %%
# !./darknet detector test data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg  backup/yolov3-tiny-obj_2000.weights /content/drive/'My Drive'/IMG-20200130-WA0003.jpg -i 0 -thresh 0.5
# Out:
#  CUDA-version: 8000 (10010)
#  Warning: CUDA-version is lower than Driver-version!
# , GPU count: 1
#  OpenCV version: 3.2.0
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#    9 max                2x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   10 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   11 max                2x 2/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.000 BF
#   12 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   13 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   14 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   15 conv     18       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  18 0.003 BF
#   16 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   17 route  13 		                           ->   13 x  13 x 256
#   18 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   19 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   20 route  19 8 	                           ->   26 x  26 x 384
#   21 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   22 conv     18       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  18 0.006 BF
#   23 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 5.448
#  Allocate additional workspace_size = 24.92 MB
# Loading weights from backup/yolov3-tiny-obj_2000.weights...
#  seen 64, trained: 128 K-images (2 Kilo-batches_64)
# Done! Loaded 24 layers from weights-file
# /content/drive/My Drive/IMG-20200130-WA0003.jpg: Predicted in 332.030000 milli-seconds.
# Unable to init server: Could not connect: Connection refused
#
# (predictions:37104): Gtk-WARNING **: 08:33:50.187: cannot open display:

# %%
imShow('predictions.jpg')

# %%
cd ..

# %%
cp /content/drive/'My Drive'/video12.mp4 /content/darknet

# %%
cd darknet
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet

# %%
ls
# Out:
# 3rdparty/                  darknet.py              obj/
# appveyor.yml               darknet_video.py        predictions.jpg
# backup/                    data/                   README.md
# build/                     data_for_colab/         results/
# build.ps1*                 data_for_colab.zip      scripts/
# build.sh*                  image_yolov2.sh*        src/
# cfg/                       image_yolov3.sh*        test.txt
# chart.png                  include/                train.txt
# chart_yolov3-tiny-obj.png  json_mjpeg_streams.sh*  veout.avi
# cmake/                     LICENSE                 video12.mp4
# CMakeLists.txt             Makefile                video_v2.sh*
# darknet*                   net_cam_v3.sh*          video_yolov3.sh*
# DarknetConfig.cmake.in     number_plate_EPS.jpg    yolov3.weights

# %%
# !./darknet detector demo data_for_colab/obj.data data_for_colab/yolov3-tiny-obj.cfg  backup/yolov3-tiny-obj_1000.weights -dont_show video12.mp4 -i 0 -thresh 0.2 -out_filename veout.avi
# Out:
#  CUDA-version: 8000 (10010)
#  Warning: CUDA-version is lower than Driver-version!
# , GPU count: 1
#  OpenCV version: 3.2.0
# Demo
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
#    8 conv    256       3 x 3/ 1     26 x  26 x 128 ->   26 x  26 x 256 0.399 BF
#    9 max                2x 2/ 2     26 x  26 x 256 ->   13 x  13 x 256 0.000 BF
#   10 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   11 max                2x 2/ 1     13 x  13 x 512 ->   13 x  13 x 512 0.000 BF
#   12 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   13 conv    256       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 256 0.089 BF
#   14 conv    512       3 x 3/ 1     13 x  13 x 256 ->   13 x  13 x 512 0.399 BF
#   15 conv     18       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x  18 0.003 BF
#   16 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
#   17 route  13 		                           ->   13 x  13 x 256
#   18 conv    128       1 x 1/ 1     13 x  13 x 256 ->   13 x  13 x 128 0.011 BF
#   19 upsample                 2x    13 x  13 x 128 ->   26 x  26 x 128
#   20 route  19 8 	                           ->   26 x  26 x 384
#   21 conv    256       3 x 3/ 1     26 x  26 x 384 ->   26 x  26 x 256 1.196 BF
#   22 conv     18       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x  18 0.006 BF
#   23 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, cls_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 5.448
#  Allocate additional workspace_size = 24.92 MB
# Loading weights from backup/yolov3-tiny-obj_1000.weights...
#  seen 64, trained: 64 K-images (1 Kilo-batches_64)
# Done! Loaded 24 layers from weights-file
# video file: video12.mp4
# Video stream: 1920 x 1080
# Objects:
#
#
# FPS:0.0 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:4.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:5.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:7.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:9.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:10.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:22.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:23.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.9 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:24.8
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.2 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.4 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.0 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.9 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:24.8 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.1 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:25.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:26.6 	 AVG_FPS:25.3
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.

# %%
download('veout.avi')

# %%
# !./darknet detector calc_anchors Dataset/obj.data -num_of_clusters 5 -width 416 -height 416
